# %%
import sys
sys.path.insert(1, "./src")

# %%
from pathlib import Path
import yaml
import pytorch_lightning as pl
from torch.utils.data import DataLoader
from transformers import set_seed


from datasets.ner_dataset import get_ner_dataset
from models.bert_model import PretrainedBertNER
from utils.metrics import Statistics
from utils.log_reader import TensorBoardReader
from anonymization.ref_book import ReferenceBookAnonymization

# %%
set_seed(42)

# %%
# Data config initialisation
i2b2_2006_data_config = yaml.load(open("configs/i2b2-2006_data_config.yaml", 'r'), Loader=yaml.Loader)
i2b2_2014_data_config = yaml.load(open("configs/i2b2-2014_data_config.yaml", 'r'), Loader=yaml.Loader)

# %%
# Model config initialisation
bert_base_model_config = yaml.load(open("configs/bert-base_model_config.yaml", 'r'), Loader=yaml.Loader)
bert_large_model_config = yaml.load(open("configs/bert-large_model_config.yaml", 'r'), Loader=yaml.Loader)

# %%
# Anonymization config initialisation
anon_config = yaml.load(open("configs/ref_book_anonymization_config.yaml", 'r'), Loader=yaml.Loader)

# %% [markdown]
# ### Структура сохранённых моделей:
# 1. В ```./bert-base/lightning_logs/``` должны храниться модели, основанные на базовом предобученном BERT
#     1. Version 0 --- обученная на датасете i2b2 2006 с учётом регистра
#     2. Version 1 --- обученная на датасете i2b2 2006 без учёта регистра
#     3. Version 2 --- обученная на датасете i2b2 2014 с учётом регистра
#     4. Version 3 --- обученная на датасете i2b2 2014 без учёта регистра
# 2. В ```./bert-large/lightning_logs/``` должны храниться модели, основанные на большом предобученном BERT
#     1. Version 0 --- обученная на датасете i2b2 2006 с учётом регистра
#     2. Version 1 --- обученная на датасете i2b2 2006 без учёта регистра
#     3. Version 2 --- обученная на датасете i2b2 2014 с учётом регистра
#     4. Version 3 --- обученная на датасете i2b2 2014 без учёта регистра

# %% [markdown]
# ### Этап 1: Сравнение результатов на наборе данных i2b2 2014
# Сравнение будет включает в себя измерение метрик Recall, Precision и $F_1$ score для следующий моделей:
# * BERT-base-cased
# * BERT-base-uncased
# * BERT-large-cased
# * BERT-large-uncased

# %% [markdown]
# #### BERT-base-cased

# %% [markdown]
# Графики обучения:
# (Метрика recall посчитана без учёта класса 'other', отвечающего за неличные сущности).

# %%
t_reader = TensorBoardReader(Path(bert_base_model_config["log_dir"]) / Path("lightning_logs"))
t_reader.plot_tensorboard_graphics(2)

# %% [markdown]
# Из обучения взята модель с лучшим показателем в метрике recall без учёта класса 'other'. Посмотрим на её метрики на валидационных данных.

# %%
# Data processing
test_dataset = get_ner_dataset(data_type=i2b2_2014_data_config['val_data_type'],
                               path_to_folder=i2b2_2014_data_config["validate_data_path"],
                               is_uncased=False,
                               pretrained_tokenizer=i2b2_2014_data_config["pretrained_tokenizer_path"],
                               max_length=i2b2_2014_data_config["max_token_number"],
                               eq_max_padding=i2b2_2014_data_config["eq_max_padding"])
test_dataloader = DataLoader(test_dataset, shuffle=False,
                             batch_size=i2b2_2014_data_config["batch_size"],
                             collate_fn=test_dataset.get_collate_fn())
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (653 > 512). Running this sequence through the model will result in indexing errors

# %%
# Model initialisation
path_to_checkpoint = t_reader.get_ckpt_path()
ner_model = PretrainedBertNER.load_from_checkpoint(path_to_checkpoint)
print(ner_model)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# PretrainedBertNER(
#   (model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (head): Sequential(
#     (0): Linear(in_features=768, out_features=384, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=384, out_features=9, bias=True)
#   )
#   (criterion): CrossEntropyLoss()
#   (train_recall): MulticlassRecall()
#   (train_precision): MulticlassPrecision()
#   (train_f1_score): MulticlassF1Score()
#   (val_recall): MulticlassRecall()
#   (val_precision): MulticlassPrecision()
#   (val_f1_score): MulticlassF1Score()
# )

# %%
# Testing
trainer_args = {
    "accelerator": "gpu",
    "logger": False
}
trainer = pl.Trainer(**trainer_args, enable_progress_bar=True)
trainer.test(ner_model, test_dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_recall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_precision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_f1', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          test_f1            0.9942045211791992
#      test_precision         0.9942045211791992
#        test_recall          0.9913195967674255
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_recall': 0.9913195967674255,
#   'test_precision': 0.9942045211791992,
#   'test_f1': 0.9942045211791992}]

# %%
# Print metrics
stats = Statistics(ner_model, test_dataloader)
print(stats.get_classification_report())
stats.plot_confusion_matrix()
stats.print_random_failed_predictions()
# Out:
#               precision    recall  f1-score   support
#
#         NAME     0.9733    0.9901    0.9816      3023
#   PROFESSION     0.0000    0.0000    0.0000        13
#     LOCATION     0.9300    0.9789    0.9538      2227
#          AGE     0.9913    0.9942    0.9927       343
#         DATE     0.9984    0.9972    0.9978      5715
#           ID     0.9923    0.9967    0.9945      1804
#      CONTACT     0.9948    0.9914    0.9931       584
#            O     0.9688    0.9953    0.9819     37538
#
#    micro avg     0.9718    0.9942    0.9829     51247
#    macro avg     0.8561    0.8680    0.8619     51247
# weighted avg     0.9717    0.9942    0.9828     51247
# Wrongly predicted examples:
# _____ Record 215-05 _____
# | Sentence:    | record | date | : | 2130 | -    | 08   | -    | 09   | cardiology | elkhorn  | valley   | clinic   | reason | for | visit | : | a | 59  | yr | old | iddm | man | s | / | p | cabg | in | 25   | with | iddm | and | chf | admitted | after | elective | cardiac | cath | which | revealed | new | rca | occlusion | for | post | hydration | / | mucomyst | / | bicarb | . | interval | history | : | cardiac | history | began | in | 2125 | with | inappropriate | sinus | tachycardia | . | a | cardiac | echo | revealed | ef | of | 64 | % | with | no | valvular | disease |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O          | LOCATION | LOCATION | LOCATION | O      | O   | O     | O | O | AGE | O  | O   | O    | O   | O | O | O | O    | O  | DATE | O    | O    | O   | O   | O        | O     | O        | O       | O    | O     | O        | O   | O   | O         | O   | O    | O         | O | O        | O | O      | O | O        | O       | O | O       | O       | O     | O  | DATE | O    | O             | O     | O           | O | O | O       | O    | O        | O  | O  | O  | O | O    | O  | O        | O       |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O          | LOCATION | LOCATION | LOCATION | O      | O   | O     | O | O | AGE | O  | O   | O    | O   | O | O | O | O    | O  | AGE  | O    | O    | O   | O   | O        | O     | O        | O       | O    | O     | O        | O   | O   | O         | O   | O    | O         | O | O        | O | O      | O | O        | O       | O | O       | O       | O     | O  | DATE | O    | O             | O     | O           | O | O | O       | O    | O        | O  | O  | O  | O | O    | O  | O        | O       |
# _____ Record 200-02 _____
# | Sentence:    | record | date | : | 2170 | -    | 03   | -    | 02   | reason | for | visit | : | week | 4 | adjuvant | chemotherapy | with | 5 | - | fu | / | lcv | diagnosis | / | treatment | summary | : | 10   | /    | 16   | /    | 69   | egd | @ | griffin  | hospital | : | long | partially | - | obstructing | distal | esophageal | well | differentiated | invasive | adenoca | , | from | 34 | - | 39 | cm | from | barrett  | ' | s | . | rare | mucin | production | . | 10   | /    | 17   | /    | 69   | ct | chest | / | abd | : | prominent | thickening | distal | esophagus | . | 10   | /    | 21   | /    |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O      | O   | O     | O | O    | O | O        | O            | O    | O | O | O  | O | O   | O         | O | O         | O       | O | DATE | DATE | DATE | DATE | DATE | O   | O | LOCATION | LOCATION | O | O    | O         | O | O           | O      | O          | O    | O              | O        | O       | O | O    | O  | O | O  | O  | O    | O        | O | O | O | O    | O     | O          | O | DATE | DATE | DATE | DATE | DATE | O  | O     | O | O   | O | O         | O          | O      | O         | O | DATE | DATE | DATE | DATE |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O      | O   | O     | O | O    | O | O        | O            | O    | O | O | O  | O | O   | O         | O | O         | O       | O | DATE | DATE | DATE | DATE | DATE | O   | O | LOCATION | LOCATION | O | O    | O         | O | O           | O      | O          | O    | O              | O        | O       | O | O    | O  | O | O  | O  | O    | LOCATION | O | O | O | O    | O     | O          | O | DATE | DATE | DATE | DATE | DATE | O  | O     | O | O   | O | O         | O          | O      | O         | O | DATE | DATE | DATE | DATE |
# _____ Record 162-01 _____
# | Sentence:    | record | date | : | 2068 | -    | 02   | -    | 04   | associated | arthritis | specialists | center   | quijano | ,    | baylee | 2    | -    | 03   | -    | 68   | identification | : | patient | is | a | 53  | - | year | old | markedly | obese | female | complaining | of | bilateral | weight | knee | pain | . | she | denies | any | morning | stiffness | , | any | jelling | phenomena | . | she | has | had | no | trauma | or | effusions | in | the | knee | . | she | had | noted | on | x | - | ray | many | years | ago | that | she | had | had | a | chipped | bone | in | the | right | knee | and | some | mild | osteoarthritis |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION   | LOCATION  | LOCATION    | LOCATION | NAME    | NAME | NAME   | DATE | DATE | DATE | DATE | DATE | O              | O | O       | O  | O | AGE | O | O    | O   | O        | O     | O      | O           | O  | O         | O      | O    | O    | O | O   | O      | O   | O       | O         | O | O   | O       | O         | O | O   | O   | O   | O  | O      | O  | O         | O  | O   | O    | O | O   | O   | O     | O  | O | O | O   | O    | O     | O   | O    | O   | O   | O   | O | O       | O    | O  | O   | O     | O    | O   | O    | O    | O              |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O          | O         | O           | LOCATION | NAME    | NAME | NAME   | DATE | DATE | DATE | DATE | DATE | O              | O | O       | O  | O | AGE | O | O    | O   | O        | O     | O      | O           | O  | O         | O      | O    | O    | O | O   | O      | O   | O       | O         | O | O   | O       | O         | O | O   | O   | O   | O  | O      | O  | O         | O  | O   | O    | O | O   | O   | O     | O  | O | O | O   | O    | O     | O   | O    | O   | O   | O   | O | O       | O    | O  | O   | O     | O    | O   | O    | O    | O              |
# _____ Record 196-03 _____
# | Sentence:    | record | date | : | 2090 | -    | 01   | -    | 03   | cc | : | f | / | up | of | htn | & | amp | ; | dm | management | hpi | : | 61  | yo | female | who | presents | back | to | clinic | having | an | upcoming | eye | appt | again | at | harmon   | doctors  | clinic   | 1    | /    | 12   | /    | 90   | . | most | recent | a1c | 8 | . | 5 | 6    | /    | 15   | /    | 89   | , | being | followed | at | ms       | . | denies | any | symptoms | of | hyperglycemia | or | hypoglycemia | . | denies | any | cp | , | increased | sob | beyond | her | baseline | , | or | headaches | . |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O  | O | O | O | O  | O  | O   | O | O   | O | O  | O          | O   | O | AGE | O  | O      | O   | O        | O    | O  | O      | O      | O  | O        | O   | O    | O     | O  | LOCATION | LOCATION | LOCATION | DATE | DATE | DATE | DATE | DATE | O | O    | O      | O   | O | O | O | DATE | DATE | DATE | DATE | DATE | O | O     | O        | O  | LOCATION | O | O      | O   | O        | O  | O             | O  | O            | O | O      | O   | O  | O | O         | O   | O      | O   | O        | O | O  | O         | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O  | O | O | O | O  | O  | O   | O | O   | O | O  | O          | O   | O | AGE | O  | O      | O   | O        | O    | O  | O      | O      | O  | O        | O   | O    | O     | O  | LOCATION | LOCATION | LOCATION | DATE | DATE | DATE | DATE | DATE | O | O    | O      | O   | O | O | O | DATE | DATE | DATE | DATE | DATE | O | O     | O        | O  | O        | O | O      | O   | O        | O  | O             | O  | O            | O | O      | O   | O  | O | O         | O   | O      | O   | O        | O | O  | O         | O |
# _____ Record 377-01 _____
# | Sentence:    | record | date | : | 2064 | -    | 07   | -    | 26   | july | 26   | ,    | 2064 | harry | r    | .    | lynn | , | m | . | d | . | doraville | county   | health   | center   | 897      | cider    | street   | platteville | , | hi       | 79812    | re | : | isabelle | y    | .    | quick | atch     | : | 655 | -  | 75 | -  | 45 | dear | harry | and  | yair | : | my | thanks | for | your | kind | referral | of | the | above | noted | patient | with | respect | to | her | disabling | claudication | and | of | course | she | is | not | in | a | very | happy | circumstance | . | as | you | know | , | she |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | DATE | DATE | DATE | DATE | NAME  | NAME | NAME | NAME | O | O | O | O | O | LOCATION  | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION    | O | LOCATION | LOCATION | O  | O | NAME     | NAME | NAME | NAME  | LOCATION | O | ID  | ID | ID | ID | ID | O    | NAME  | O    | NAME | O | O  | O      | O   | O    | O    | O        | O  | O   | O     | O     | O       | O    | O       | O  | O   | O         | O            | O   | O  | O      | O   | O  | O   | O  | O | O    | O     | O            | O | O  | O   | O    | O | O   |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | DATE | DATE | DATE | DATE | NAME  | NAME | NAME | NAME | O | O | O | O | O | LOCATION  | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION    | O | LOCATION | LOCATION | O  | O | NAME     | NAME | NAME | NAME  | O        | O | ID  | ID | ID | ID | ID | O    | NAME  | NAME | NAME | O | O  | O      | O   | O    | O    | O        | O  | O   | O     | O     | O       | O    | O       | O  | O   | O         | O            | O   | O  | O      | O   | O  | O   | O  | O | O    | O     | O            | O | O  | O   | O    | O | O   |

# %% [markdown]
# #### BERT-base-uncased

# %% [markdown]
# Графики обучения:
# (Метрика recall посчитана без учёта класса 'other', отвечающего за неличные сущности).

# %%
t_reader = TensorBoardReader(Path(bert_base_model_config["log_dir"]) / Path("lightning_logs"))
t_reader.plot_tensorboard_graphics(3)

# %% [markdown]
# Из обучения взята модель с лучшим показателем в метрике recall без учёта класса 'other'. Посмотрим на её метрики на валидационных данных.

# %%
# Data processing
test_dataset = get_ner_dataset(data_type=i2b2_2014_data_config['val_data_type'],
                               path_to_folder=i2b2_2014_data_config["validate_data_path"],
                               is_uncased=True,
                               pretrained_tokenizer=i2b2_2014_data_config["pretrained_tokenizer_path"],
                               max_length=i2b2_2014_data_config["max_token_number"],
                               eq_max_padding=i2b2_2014_data_config["eq_max_padding"])
test_dataloader = DataLoader(test_dataset, shuffle=False,
                             batch_size=i2b2_2014_data_config["batch_size"],
                             collate_fn=test_dataset.get_collate_fn())
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (653 > 512). Running this sequence through the model will result in indexing errors

# %%
# Model initialisation
path_to_checkpoint = t_reader.get_ckpt_path()
ner_model = PretrainedBertNER.load_from_checkpoint(path_to_checkpoint)
print(ner_model)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# PretrainedBertNER(
#   (model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (head): Sequential(
#     (0): Linear(in_features=768, out_features=384, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=384, out_features=9, bias=True)
#   )
#   (criterion): CrossEntropyLoss()
#   (train_recall): MulticlassRecall()
#   (train_precision): MulticlassPrecision()
#   (train_f1_score): MulticlassF1Score()
#   (val_recall): MulticlassRecall()
#   (val_precision): MulticlassPrecision()
#   (val_f1_score): MulticlassF1Score()
# )

# %%
# Testing
trainer_args = {
    "accelerator": "gpu",
    "logger": False
}
trainer = pl.Trainer(**trainer_args, enable_progress_bar=True)
trainer.test(ner_model, test_dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_recall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_precision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_f1', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          test_f1            0.9942045211791992
#      test_precision         0.9942045211791992
#        test_recall          0.9913195967674255
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_recall': 0.9913195967674255,
#   'test_precision': 0.9942045211791992,
#   'test_f1': 0.9942045211791992}]

# %%
# Print metrics
stats = Statistics(ner_model, test_dataloader)
print(stats.get_classification_report())
stats.plot_confusion_matrix()
stats.print_random_failed_predictions()
# Out:
#               precision    recall  f1-score   support
#
#         NAME     0.9733    0.9901    0.9816      3023
#   PROFESSION     0.0000    0.0000    0.0000        13
#     LOCATION     0.9300    0.9789    0.9538      2227
#          AGE     0.9913    0.9942    0.9927       343
#         DATE     0.9984    0.9972    0.9978      5715
#           ID     0.9923    0.9967    0.9945      1804
#      CONTACT     0.9948    0.9914    0.9931       584
#            O     0.9688    0.9953    0.9819     37538
#
#    micro avg     0.9718    0.9942    0.9829     51247
#    macro avg     0.8561    0.8680    0.8619     51247
# weighted avg     0.9717    0.9942    0.9828     51247
# Wrongly predicted examples:
# _____ Record 197-04 _____
# | Sentence:    | record | date | : | 2098 | -    | 12   | -    | 10   | 059 | -  | 57 | -  | 26 | emery | ,    | donn | december | 10   | ,    | 2098 | endocrine | / | diabetes | present | illness | : | asked | to | see | this | 89  | year | old | patient | of | drs | . | pina | and  | keefe | , | admitted | with | an | acute | exacerbation | of | congestive | heart | failure | in | the | context | of | severe | aortic | stenosis | and | less | attention | to | diet | at | the | time | of | his | wife | ' | s | death | last | week | . | he | is | approaching | probable | avr | and | ? |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | ID  | ID | ID | ID | ID | NAME  | NAME | NAME | DATE     | DATE | DATE | DATE | O         | O | O        | O       | O       | O | O     | O  | O   | O    | AGE | O    | O   | O       | O  | O   | O | NAME | O    | NAME  | O | O        | O    | O  | O     | O            | O  | O          | O     | O       | O  | O   | O       | O  | O      | O      | O        | O   | O    | O         | O  | O    | O  | O   | O    | O  | O   | O    | O | O | O     | O    | O    | O | O  | O  | O           | O        | O   | O   | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | ID  | ID | ID | ID | ID | NAME  | NAME | NAME | DATE     | DATE | DATE | DATE | O         | O | O        | O       | O       | O | O     | O  | O   | O    | AGE | O    | O   | O       | O  | O   | O | NAME | NAME | NAME  | O | O        | O    | O  | O     | O            | O  | O          | O     | O       | O  | O   | O       | O  | O      | O      | O        | O   | O    | O         | O  | O    | O  | O   | O    | O  | O   | O    | O | O | O     | O    | O    | O | O  | O  | O           | O        | O   | O   | O |
# _____ Record 130-04 _____
# | Sentence:    | record | date | : | 2089 | -    | 03   | -    | 29   | internal | medicine | intern | admission | note | patient | fh       | mrn | : | 57585291 | attending | : | dr | . | olivia | perry | primary | care | : | dr | . | qiana | solomon | , | emmons   | health   | counseling | center   | , | 665     | -       | 578     | -       | 7821    | hcp | : | quanita | -    | ella | paul | -    | doyle | ( | daughter | ) | , | : | 448     | -       | 876     | -       | 4285    | cc | : | left | thigh | pain | , | inability | to | ambulate | hpi | : | 77  | f | with | esrd | ( | secondary | to |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O        | O        | O      | O         | O    | O       | O        | O   | O | ID       | O         | O | O  | O | NAME   | NAME  | O       | O    | O | O  | O | NAME  | NAME    | O | LOCATION | LOCATION | LOCATION   | LOCATION | O | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | O   | O | NAME    | NAME | NAME | NAME | NAME | NAME  | O | O        | O | O | O | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | O  | O | O    | O     | O    | O | O         | O  | O        | O   | O | AGE | O | O    | O    | O | O         | O  |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O        | O        | O      | O         | O    | O       | LOCATION | O   | O | ID       | O         | O | O  | O | NAME   | NAME  | O       | O    | O | O  | O | NAME  | NAME    | O | LOCATION | LOCATION | LOCATION   | LOCATION | O | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | O   | O | NAME    | NAME | NAME | NAME | NAME | NAME  | O | O        | O | O | O | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | O  | O | O    | O     | O    | O | O         | O  | O        | O   | O | AGE | O | O    | O    | O | O         | O  |
# _____ Record 340-03 _____
# | Sentence:    | record | date | : | 2077 | -    | 01   | -    | 22   | carolyn  | huntington | bailey   | health   | center   | 592      | kristina | street   | xia  | ,    | jean | north    | east     | , | al       | 81699    | 58269151 | (       | 375     | )       | 512     | -       | 0897    | 01   | /    | 22   | /    | 77   | history | of | present | illness | : | ms | . | xia  | is | a | 57  | - | year | - | old | woman | who | comes | in | for | evaluation | of | treatment | of | diabetes | and | hypertension | , | reporting | that | for | the | last | 3 | days | she | has | had | trouble | with | her | vision | , | her | blood | pressure | has | been | high | . |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | LOCATION   | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | NAME | NAME | NAME | LOCATION | LOCATION | O | LOCATION | LOCATION | ID       | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O       | O  | O       | O       | O | O  | O | NAME | O  | O | AGE | O | O    | O | O   | O     | O   | O     | O  | O   | O          | O  | O         | O  | O        | O   | O            | O | O         | O    | O   | O   | O    | O | O    | O   | O   | O   | O       | O    | O   | O      | O | O   | O     | O        | O   | O    | O    | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME     | NAME       | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | NAME | NAME | NAME | LOCATION | LOCATION | O | LOCATION | LOCATION | ID       | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O       | O  | O       | O       | O | O  | O | NAME | O  | O | AGE | O | O    | O | O   | O     | O   | O     | O  | O   | O          | O  | O         | O  | O        | O   | O            | O | O         | O    | O   | O   | O    | O | O    | O   | O   | O   | O       | O    | O   | O      | O | O   | O     | O        | O   | O    | O    | O |
# _____ Record 318-02 _____
# | Sentence:    | record | date | : | 2095 | -    | 09   | -    | 19   | kekela   | inpatient | dialysis | admit | note | name | : | marsh | ,    | carl | mrn | : | 99579205 | primary | care | md | : | xavier | t    | .    | mccoy | outpatient | nephrologist | : | keith | tierney | outpatient | dialysis | unit | : | sanford  | memorial | hospital | , | s    | and | t    | estimated | dry | weight | : | 61 | kg | dialysis | access | : | left | avf | reason | for | admission | : | body | jerking | since | last | night | hpi | : | 74  | year | old | turkmenistan | male | with | a | past | medical | history | of | esrd | presumably |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | O         | O        | O     | O    | O    | O | NAME  | NAME | NAME | O   | O | ID       | O       | O    | O  | O | NAME   | NAME | NAME | NAME  | O          | O            | O | NAME  | NAME    | O          | O        | O    | O | LOCATION | LOCATION | LOCATION | O | DATE | O   | DATE | O         | O   | O      | O | O  | O  | O        | O      | O | O    | O   | O      | O   | O         | O | O    | O       | O     | O    | O     | O   | O | AGE | O    | O   | LOCATION     | O    | O    | O | O    | O       | O       | O  | O    | O          |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | O         | O        | O     | O    | O    | O | NAME  | NAME | NAME | O   | O | ID       | O       | O    | O  | O | NAME   | NAME | NAME | NAME  | O          | O            | O | NAME  | NAME    | O          | O        | O    | O | LOCATION | LOCATION | LOCATION | O | O    | O   | O    | O         | O   | O      | O | O  | O  | O        | O      | O | O    | O   | O      | O   | O         | O | O    | O       | O     | O    | O     | O   | O | AGE | O    | O   | LOCATION     | O    | O    | O | O    | O       | O       | O  | O    | O          |
# _____ Record 374-03 _____
# | Sentence:    | record | date | : | 2133 | -    | 01   | -    | 22   | wise | ,    | willa | internal | medicine | associates | , | suite | 7 | bayne    | -        | jones    | army     | community | hospital | , | 0th | floor | , | noom | 038 | hayti    | ,        | de       | , | 36349    | -        | 2179     | re | : | norma | mckee | 01   | /    | 22   | /    | 2133 | admission | note | ima | consult | note | covering | for | dr | robert | xenakis | cc | 57  | yo | with | multiple | medical | , | psychiatric | problems | admitted | with | recurrent | sbo | and | acute | renal | failure | hpi | pt | has | hx | tab | / | bso | , |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME | NAME | NAME  | O        | O        | O          | O | O     | O | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION  | LOCATION | O | O   | O     | O | O    | O   | LOCATION | O        | LOCATION | O | LOCATION | LOCATION | LOCATION | O  | O | NAME  | NAME  | DATE | DATE | DATE | DATE | DATE | O         | O    | O   | O       | O    | O        | O   | O  | NAME   | NAME    | O  | AGE | O  | O    | O        | O       | O | O           | O        | O        | O    | O         | O   | O   | O     | O     | O       | O   | O  | O   | O  | O   | O | O   | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME | NAME | NAME  | O        | O        | O          | O | O     | O | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION  | LOCATION | O | O   | O     | O | O    | O   | LOCATION | LOCATION | LOCATION | O | LOCATION | LOCATION | LOCATION | O  | O | NAME  | NAME  | DATE | DATE | DATE | DATE | DATE | O         | O    | O   | O       | O    | O        | O   | O  | NAME   | NAME    | O  | AGE | O  | O    | O        | O       | O | O           | O        | O        | O    | O         | O   | O   | O     | O     | O       | O   | O  | O   | O  | O   | O | O   | O |

# %% [markdown]
# #### BERT-large-cased

# %% [markdown]
# Графики обучения:
# (Метрика recall посчитана без учёта класса 'other', отвечающего за неличные сущности).

# %%
t_reader = TensorBoardReader(Path(bert_large_model_config["log_dir"]) / Path("lightning_logs"))
t_reader.plot_tensorboard_graphics(2)

# %% [markdown]
# Из обучения взята модель с лучшим показателем в метрике recall без учёта класса 'other'. Посмотрим на её метрики на валидационных данных.

# %%
# Data processing
test_dataset = get_ner_dataset(data_type=i2b2_2014_data_config['val_data_type'],
                               path_to_folder=i2b2_2014_data_config["validate_data_path"],
                               is_uncased=False,
                               pretrained_tokenizer=i2b2_2014_data_config["pretrained_tokenizer_path"],
                               max_length=i2b2_2014_data_config["max_token_number"],
                               eq_max_padding=i2b2_2014_data_config["eq_max_padding"])
test_dataloader = DataLoader(test_dataset, shuffle=False,
                             batch_size=i2b2_2014_data_config["batch_size"],
                             collate_fn=test_dataset.get_collate_fn())
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (653 > 512). Running this sequence through the model will result in indexing errors

# %%
# Model initialisation
path_to_checkpoint = t_reader.get_ckpt_path()
ner_model = PretrainedBertNER.load_from_checkpoint(path_to_checkpoint)
print(ner_model)
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# PretrainedBertNER(
#   (model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 1024, padding_idx=0)
#       (position_embeddings): Embedding(512, 1024)
#       (token_type_embeddings): Embedding(2, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-23): 24 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=1024, out_features=1024, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (head): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=9, bias=True)
#   )
#   (criterion): CrossEntropyLoss()
#   (train_recall): MulticlassRecall()
#   (train_precision): MulticlassPrecision()
#   (train_f1_score): MulticlassF1Score()
#   (val_recall): MulticlassRecall()
#   (val_precision): MulticlassPrecision()
#   (val_f1_score): MulticlassF1Score()
# )

# %%
# Testing
trainer_args = {
    "accelerator": "gpu",
    "logger": False
}
trainer = pl.Trainer(**trainer_args, enable_progress_bar=True)
trainer.test(ner_model, test_dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_recall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_precision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_f1', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          test_f1            0.9950436353683472
#      test_precision         0.9950436353683472
#        test_recall          0.9922678470611572
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_recall': 0.9922678470611572,
#   'test_precision': 0.9950436353683472,
#   'test_f1': 0.9950436353683472}]

# %%
# Print metrics
stats = Statistics(ner_model, test_dataloader)
print(stats.get_classification_report())
stats.plot_confusion_matrix()
stats.print_random_failed_predictions()
# Out:
#               precision    recall  f1-score   support
#
#         NAME     0.9727    0.9904    0.9815      3023
#   PROFESSION     1.0000    0.3077    0.4706        13
#     LOCATION     0.9454    0.9793    0.9621      2227
#          AGE     0.9552    0.9942    0.9743       343
#         DATE     0.9983    0.9984    0.9983      5715
#           ID     0.9934    0.9956    0.9945      1804
#      CONTACT     0.9748    0.9949    0.9847       584
#            O     0.9696    0.9961    0.9827     37538
#
#    micro avg     0.9726    0.9950    0.9837     51247
#    macro avg     0.9762    0.9071    0.9186     51247
# weighted avg     0.9727    0.9950    0.9837     51247
# Wrongly predicted examples:
# _____ Record 164-05 _____
# | Sentence:    | record | date | : | 2085 | -    | 06   | -    | 16   | 83  | yo | male | for | f | / | u | of | heart | disease | and | bp | . | he | states | he | is | fine | and | denies | any | chest | pressure | , | dyspnea | or | abd | pain | . | denies | any | bleeding | from | stools | . | problems | mental | retardation | hypertension | anemia | benign | prostatic | hypertrophy | : | s | / | p | turp | 4    | /    | 84   | h | / | o | peptic | ulcer | disease | : | dx | . | by | upper | endoscopy | in | 2069 | . | coronary | artery | disease | : |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | AGE | O  | O    | O   | O | O | O | O  | O     | O       | O   | O  | O | O  | O      | O  | O  | O    | O   | O      | O   | O     | O        | O | O       | O  | O   | O    | O | O      | O   | O        | O    | O      | O | O        | O      | O           | O            | O      | O      | O         | O           | O | O | O | O | O    | DATE | DATE | DATE | O | O | O | O      | O     | O       | O | O  | O | O  | O     | O         | O  | DATE | O | O        | O      | O       | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | AGE | O  | O    | O   | O | O | O | O  | O     | O       | O   | O  | O | O  | O      | O  | O  | O    | O   | O      | O   | O     | O        | O | O       | O  | O   | O    | O | O      | O   | O        | O    | O      | O | O        | O      | O           | O            | O      | O      | O         | O           | O | O | O | O | O    | O    | DATE | DATE | O | O | O | O      | O     | O       | O | O  | O | O  | O     | O         | O  | DATE | O | O        | O      | O       | O |
# _____ Record 383-03 _____
# | Sentence:    | record | date | : | 2119 | -    | 12   | -    | 22   | radiology | h | & | amp | ; | p | pt | : | werner | ,    | brian | u    | mrn | : | 4097229 | date | : | 12   | /    | 22   | /    | 2119 | 10 | : | 56h | cc | : | elective | left | carotid | artery | stent | placement | hpi | : | 73  | yo | rhm | with | h | / | o | left | pca | stroke | ( | residual | right | partial | visual | field | cut | ) | and | h | / | o | bilateral | carotid | endarterectomies | having | recurrent | stenosis | of | left | ica |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O         | O | O | O   | O | O | O  | O | NAME   | NAME | NAME  | NAME | O   | O | ID      | O    | O | DATE | DATE | DATE | DATE | DATE | O  | O | O   | O  | O | O        | O    | O       | O      | O     | O         | O   | O | AGE | O  | O   | O    | O | O | O | O    | O   | O      | O | O        | O     | O       | O      | O     | O   | O | O   | O | O | O | O         | O       | O                | O      | O         | O        | O  | O    | O   |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O         | O | O | O   | O | O | O  | O | NAME   | NAME | NAME  | O    | O   | O | ID      | O    | O | DATE | DATE | DATE | DATE | DATE | O  | O | O   | O  | O | O        | O    | O       | O      | O     | O         | O   | O | AGE | O  | O   | O    | O | O | O | O    | O   | O      | O | O        | O     | O       | O      | O     | O   | O | O   | O | O | O | O         | O       | O                | O      | O         | O        | O  | O    | O   |
# _____ Record 268-01 _____
# | Sentence:    | record | date | : | 2089 | -    | 02   | -    | 20   | vi   | k    | .    | xayarath | , | m | . | d | . | , | ph | . | d | . | resident | , | phoenix  | neurology | neurology | ed | consult | date | : | thursday | ,    | february | 20   | ,    | 2089 | 21 | : | 42 | pcp | : | rhonda | riddle | ; | ( | called | by | valerie | xian | ) | patient | : | garrison | sexton | hdh      | record | # | 4210443 | chief | complaint | : | " | dizzy | , | slurred | speech | " | history | of | present | illness | : | 65  | year | old | rh       | gentleman | with |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME | NAME | NAME | NAME     | O | O | O | O | O | O | O  | O | O | O | O        | O | LOCATION | O         | O         | O  | O       | O    | O | DATE     | DATE | DATE     | DATE | DATE | DATE | O  | O | O  | O   | O | NAME   | NAME   | O | O | O      | O  | NAME    | NAME | O | O       | O | NAME     | NAME   | LOCATION | O      | O | ID      | O     | O         | O | O | O     | O | O       | O      | O | O       | O  | O       | O       | O | AGE | O    | O   | O        | O         | O    |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME | NAME | NAME | NAME     | O | O | O | O | O | O | O  | O | O | O | O        | O | LOCATION | O         | O         | O  | O       | O    | O | DATE     | DATE | DATE     | DATE | DATE | DATE | O  | O | O  | O   | O | NAME   | NAME   | O | O | O      | O  | NAME    | NAME | O | O       | O | NAME     | NAME   | LOCATION | O      | O | ID      | O     | O         | O | O | O     | O | O       | O      | O | O       | O  | O       | O       | O | AGE | O    | O   | LOCATION | O         | O    |
# _____ Record 134-01 _____
# | Sentence:    | record | date | : | 2088 | -    | 01   | -    | 20   | pcc      | internal | medicine | primary | care | 630      | poliquin | drive    | , | 642      | asmara   | , | pa       | 96931    | re | : | jarvis | ,    | amador | pcc      | # | : | 090 | -  | 73 | -  | 07 | january | 20   | ,    | 2088 | reason | for | visit | : | mr | . | jarvis | comes | to | follow | up | on | his | hypertension | , | hyperglycemia | , | renal | insufficiency | and | elevated | psa | . | history | of | present | illness | : | he | has | seen | dr | . | jose | quirk | and | a | prostate | biopsy |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | O        | O        | O       | O    | LOCATION | LOCATION | LOCATION | O | O        | LOCATION | O | LOCATION | LOCATION | O  | O | NAME   | NAME | NAME   | LOCATION | O | O | ID  | ID | ID | ID | ID | DATE    | DATE | DATE | DATE | O      | O   | O     | O | O  | O | NAME   | O     | O  | O      | O  | O  | O   | O            | O | O             | O | O     | O             | O   | O        | O   | O | O       | O  | O       | O       | O | O  | O   | O    | O  | O | NAME | NAME  | O   | O | O        | O      |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | O        | O        | O       | O    | LOCATION | LOCATION | LOCATION | O | LOCATION | LOCATION | O | LOCATION | LOCATION | O  | O | NAME   | NAME | NAME   | LOCATION | O | O | ID  | ID | ID | ID | ID | DATE    | DATE | DATE | DATE | O      | O   | O     | O | O  | O | NAME   | O     | O  | O      | O  | O  | O   | O            | O | O             | O | O     | O             | O   | O        | O   | O | O       | O  | O       | O       | O | O  | O   | O    | O  | O | NAME | NAME  | O   | O | O        | O      |
# _____ Record 214-02 _____
# | Sentence:    | record | date | : | 2096 | -    | 08   | -    | 02   | graydon | harold | jean | , | md | nevada   | hospital | internal | medicine | 01       | dan      | chan     | angels   | city     | , | nh       | 31731    | dear | gray | : | i | had | the | pleasure | of | seeing | your | patient | mr | . | henry | oswaldo | in | clinic | today | . | as | you | know | , | he | is | a | 78  | - | year | - | old | gentleman | with | diabetes | who | was | hospitalized | at | 06   | /    | 28   | /    | 2096 | in | quito    | with | any | acute | coronary | syndrome | with | anterior | myocardial | infarction | . | i | am | seeing | him | on | your | request | to | evaluate |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME    | NAME   | NAME | O | O  | LOCATION | LOCATION | O        | O        | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | O | LOCATION | LOCATION | O    | NAME | O | O | O   | O   | O        | O  | O      | O    | O       | O  | O | NAME  | NAME    | O  | O      | O     | O | O  | O   | O    | O | O  | O  | O | AGE | O | O    | O | O   | O         | O    | O        | O   | O   | O            | O  | DATE | DATE | DATE | DATE | DATE | O  | LOCATION | O    | O   | O     | O        | O        | O    | O        | O          | O          | O | O | O  | O      | O   | O  | O    | O       | O  | O        |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME    | NAME   | NAME | O | O  | LOCATION | LOCATION | O        | O        | O        | NAME     | NAME     | LOCATION | LOCATION | O | LOCATION | LOCATION | O    | NAME | O | O | O   | O   | O        | O  | O      | O    | O       | O  | O | NAME  | NAME    | O  | O      | O     | O | O  | O   | O    | O | O  | O  | O | AGE | O | O    | O | O   | O         | O    | O        | O   | O   | O            | O  | DATE | DATE | DATE | DATE | DATE | O  | LOCATION | O    | O   | O     | O        | O        | O    | O        | O          | O          | O | O | O  | O      | O   | O  | O    | O       | O  | O        |

# %% [markdown]
# #### BERT-base-cased

# %% [markdown]
# Графики обучения:
# (Метрика recall посчитана без учёта класса 'other', отвечающего за неличные сущности).

# %%
t_reader = TensorBoardReader(Path(bert_large_model_config["log_dir"]) / Path("lightning_logs"))
t_reader.plot_tensorboard_graphics(3)

# %% [markdown]
# Из обучения взята модель с лучшим показателем в метрике recall без учёта класса 'other'. Посмотрим на её метрики на валидационных данных.

# %%
# Data processing
test_dataset = get_ner_dataset(data_type=i2b2_2014_data_config['val_data_type'],
                               path_to_folder=i2b2_2014_data_config["validate_data_path"],
                               is_uncased=True,
                               pretrained_tokenizer=i2b2_2014_data_config["pretrained_tokenizer_path"],
                               max_length=i2b2_2014_data_config["max_token_number"],
                               eq_max_padding=i2b2_2014_data_config["eq_max_padding"])
test_dataloader = DataLoader(test_dataset, shuffle=False,
                             batch_size=i2b2_2014_data_config["batch_size"],
                             collate_fn=test_dataset.get_collate_fn())
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (653 > 512). Running this sequence through the model will result in indexing errors

# %%
# Model initialisation
path_to_checkpoint = t_reader.get_ckpt_path()
ner_model = PretrainedBertNER.load_from_checkpoint(path_to_checkpoint)
print(ner_model)
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# PretrainedBertNER(
#   (model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 1024, padding_idx=0)
#       (position_embeddings): Embedding(512, 1024)
#       (token_type_embeddings): Embedding(2, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-23): 24 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=1024, out_features=1024, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (head): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=9, bias=True)
#   )
#   (criterion): CrossEntropyLoss()
#   (train_recall): MulticlassRecall()
#   (train_precision): MulticlassPrecision()
#   (train_f1_score): MulticlassF1Score()
#   (val_recall): MulticlassRecall()
#   (val_precision): MulticlassPrecision()
#   (val_f1_score): MulticlassF1Score()
# )

# %%
# Testing
trainer_args = {
    "accelerator": "gpu",
    "logger": False
}
trainer = pl.Trainer(**trainer_args, enable_progress_bar=True)
trainer.test(ner_model, test_dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_recall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_precision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_f1', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          test_f1            0.9950436353683472
#      test_precision         0.9950436353683472
#        test_recall          0.9922678470611572
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_recall': 0.9922678470611572,
#   'test_precision': 0.9950436353683472,
#   'test_f1': 0.9950436353683472}]

# %%
# Print metrics
stats = Statistics(ner_model, test_dataloader)
print(stats.get_classification_report())
stats.plot_confusion_matrix()
stats.print_random_failed_predictions()
# Out:
#               precision    recall  f1-score   support
#
#         NAME     0.9727    0.9904    0.9815      3023
#   PROFESSION     1.0000    0.3077    0.4706        13
#     LOCATION     0.9454    0.9793    0.9621      2227
#          AGE     0.9552    0.9942    0.9743       343
#         DATE     0.9983    0.9984    0.9983      5715
#           ID     0.9934    0.9956    0.9945      1804
#      CONTACT     0.9748    0.9949    0.9847       584
#            O     0.9696    0.9961    0.9827     37538
#
#    micro avg     0.9726    0.9950    0.9837     51247
#    macro avg     0.9762    0.9071    0.9186     51247
# weighted avg     0.9727    0.9950    0.9837     51247
# Wrongly predicted examples:
# _____ Record 214-03 _____
# | Sentence:    | record | date | : | 2096 | -    | 10   | -    | 04   | graydon | harold | jean | , | md | nevada   | hospital | internal | medicine | 72       | dan      | chan     | angels   | city     | , | nh       | 31731    | dear | dr | . | jean | : | your | patient | henry | oswaldo | was | seen | today | by | myself | at | the | atmore   | community | hospital | today | following | coronary | artery | bypass | on | august | 15   | ,    | 2096 | . | he | has | had | a | relatively | unremarkable | recovery | with | out | complication | . | today | , | mr | . | oswaldo | looks | and | feels | well | , | and | complains | of | no | issues | . | on | examination | , | the | lungs |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME    | NAME   | NAME | O | O  | LOCATION | LOCATION | O        | O        | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | O | LOCATION | LOCATION | O    | O  | O | NAME | O | O    | O       | NAME  | NAME    | O   | O    | O     | O  | O      | O  | O   | LOCATION | LOCATION  | LOCATION | O     | O         | O        | O      | O      | O  | DATE   | DATE | DATE | DATE | O | O  | O   | O   | O | O          | O            | O        | O    | O   | O            | O | O     | O | O  | O | NAME    | O     | O   | O     | O    | O | O   | O         | O  | O  | O      | O | O  | O           | O | O   | O     |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME    | NAME   | NAME | O | O  | LOCATION | LOCATION | O        | O        | AGE      | NAME     | NAME     | LOCATION | LOCATION | O | LOCATION | LOCATION | O    | O  | O | NAME | O | O    | O       | NAME  | NAME    | O   | O    | O     | O  | O      | O  | O   | LOCATION | LOCATION  | LOCATION | O     | O         | O        | O      | O      | O  | DATE   | DATE | DATE | DATE | O | O  | O   | O   | O | O          | O            | O        | O    | O   | O            | O | O     | O | O  | O | NAME    | O     | O   | O     | O    | O | O   | O         | O  | O  | O      | O | O  | O           | O | O   | O     |
# _____ Record 314-04 _____
# | Sentence:    | record | date | : | 2094 | -    | 12   | -    | 08   | neurology | resident | ed | consult | note | patient | name | : | trent | ,    | shirley | mrn | : | 99210914 | date | : | 12   | /    | 08   | /    | 94   | pcp | : | dr | . | rose | irvin | -    | ly   | cc | : | right | sided | weakness | hpi | : | the | patient | is | a | 70  | year | - | old | right | - | handed | dutch    | - | speaking | female | with | history | of | dm | , | pvd | presenting | to | ed | with | right | - | sided | weakness | which | started | yesterday | morning | . | the | patient | ' | s | grand | - | nephew | is |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O         | O        | O  | O       | O    | O       | O    | O | NAME  | NAME | NAME    | O   | O | ID       | O    | O | DATE | DATE | DATE | DATE | DATE | O   | O | O  | O | NAME | NAME  | NAME | NAME | O  | O | O     | O     | O        | O   | O | O   | O       | O  | O | AGE | O    | O | O   | O     | O | O      | LOCATION | O | O        | O      | O    | O       | O  | O  | O | O   | O          | O  | O  | O    | O     | O | O     | O        | O     | O       | O         | O       | O | O   | O       | O | O | O     | O | O      | O  |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O         | O        | O  | O       | O    | O       | O    | O | NAME  | NAME | NAME    | O   | O | ID       | O    | O | DATE | DATE | DATE | DATE | DATE | O   | O | O  | O | NAME | NAME  | O    | NAME | O  | O | O     | O     | O        | O   | O | O   | O       | O  | O | AGE | O    | O | O   | O     | O | O      | LOCATION | O | O        | O      | O    | O       | O  | O  | O | O   | O          | O  | O  | O    | O     | O | O     | O        | O     | O       | O         | O       | O | O   | O       | O | O | O     | O | O      | O  |
# _____ Record 389-02 _____
# | Sentence:    | record | date | : | 2132 | -    | 05   | -    | 27   | date | 5    | /    | 27   | /    | 32   | time | 4am | team | e | admission | note | patient | : | pearson | ,    | tyler | medical | record | number | : | 727 | 19 | 02 | room | : | j8845i | date | of | admission | : | 5    | /    | 26   | /    | 32   | pcp | : | yale     | triplett | ( | turner   | clinic   | ) | attending | physician | : | arias | / | wesley | admitting | intern | : | jaquan | mahoney | code | status | : | full | code | source | : | patient | , | medical | record | id | / | cc | : | 87  | yom | h | / | o | copd | , |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O    | DATE | DATE | DATE | DATE | DATE | O    | O   | O    | O | O         | O    | O       | O | NAME    | NAME | NAME  | O       | O      | O      | O | ID  | ID | ID | O    | O | O      | O    | O  | O         | O | DATE | DATE | DATE | DATE | DATE | O   | O | NAME     | NAME     | O | LOCATION | LOCATION | O | O         | O         | O | NAME  | O | NAME   | O         | O      | O | NAME   | NAME    | O    | O      | O | O    | O    | O      | O | O       | O | O       | O      | O  | O | O  | O | AGE | O   | O | O | O | O    | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O    | DATE | DATE | DATE | DATE | DATE | O    | O   | O    | O | O         | O    | O       | O | NAME    | NAME | NAME  | O       | O      | O      | O | ID  | ID | ID | O    | O | ID     | O    | O  | O         | O | DATE | DATE | DATE | DATE | DATE | O   | O | LOCATION | LOCATION | O | LOCATION | LOCATION | O | O         | O         | O | NAME  | O | NAME   | O         | O      | O | NAME   | NAME    | O    | O      | O | O    | O    | O      | O | O       | O | O       | O      | O  | O | O  | O | AGE | O   | O | O | O | O    | O |
# _____ Record 373-02 _____
# | Sentence:    | record | date | : | 2083 | -    | 09   | -    | 10   | woodstock | e        | intern | admit | note | patient | : | jimenez | ,    | youssef | lch      | unit | number | : | 055 | 47 | 33 | date | of | admission | : | 09   | september | 2083 | attending | physician | : | nathan | yearwood | , | md | room | : | woodstock | 5599    | u | code | status | : | full | pcp | : | charles | eggers | , | md | of | seminole | oncologist | : | ernest | byers | , | md | source | : | patient | chief | complaint | : | doe | history | of | the | present | illness | : | patient | is | a | 74  | year | - | old | man | with | stage |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION  | O        | O      | O     | O    | O       | O | NAME    | NAME | NAME    | LOCATION | O    | O      | O | ID  | ID | ID | O    | O  | O         | O | DATE | DATE      | DATE | O         | O         | O | NAME   | NAME     | O | O  | O    | O | LOCATION  | O       | O | O    | O      | O | O    | O   | O | NAME    | NAME   | O | O  | O  | LOCATION | O          | O | NAME   | NAME  | O | O  | O      | O | O       | O     | O         | O | O   | O       | O  | O   | O       | O       | O | O       | O  | O | AGE | O    | O | O   | O   | O    | O     |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION  | LOCATION | O      | O     | O    | O       | O | NAME    | NAME | NAME    | LOCATION | O    | O      | O | ID  | ID | ID | O    | O  | O         | O | DATE | DATE      | DATE | O         | O         | O | NAME   | NAME     | O | O  | O    | O | LOCATION  | CONTACT | O | O    | O      | O | O    | O   | O | NAME    | NAME   | O | O  | O  | LOCATION | O          | O | NAME   | NAME  | O | O  | O      | O | O       | O     | O         | O | O   | O       | O  | O   | O       | O       | O | O       | O  | O | AGE | O    | O | O   | O   | O    | O     |
# _____ Record 215-05 _____
# | Sentence:    | record | date | : | 2130 | -    | 08   | -    | 09   | cardiology | elkhorn  | valley   | clinic   | reason | for | visit | : | a | 59  | yr | old | iddm | man | s | / | p | cabg | in | 25   | with | iddm | and | chf | admitted | after | elective | cardiac | cath | which | revealed | new | rca | occlusion | for | post | hydration | / | mucomyst | / | bicarb | . | interval | history | : | cardiac | history | began | in | 2125 | with | inappropriate | sinus | tachycardia | . | a | cardiac | echo | revealed | ef | of | 64 | % | with | no | valvular | disease |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O          | LOCATION | LOCATION | LOCATION | O      | O   | O     | O | O | AGE | O  | O   | O    | O   | O | O | O | O    | O  | DATE | O    | O    | O   | O   | O        | O     | O        | O       | O    | O     | O        | O   | O   | O         | O   | O    | O         | O | O        | O | O      | O | O        | O       | O | O       | O       | O     | O  | DATE | O    | O             | O     | O           | O | O | O       | O    | O        | O  | O  | O  | O | O    | O  | O        | O       |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O          | LOCATION | LOCATION | LOCATION | O      | O   | O     | O | O | AGE | O  | O   | O    | O   | O | O | O | O    | O  | AGE  | O    | O    | O   | O   | O        | O     | O        | O       | O    | O     | O        | O   | O   | O         | O   | O    | O         | O | O        | O | O      | O | O        | O       | O | O       | O       | O     | O  | DATE | O    | O             | O     | O           | O | O | O       | O    | O        | O  | O  | O  | O | O    | O  | O        | O       |

# %% [markdown]
# ### Этап 2: Демонстрация результатов на наборе данных i2b2 2006
# Демонстрация включает в себя измерение метрик Recall, Precision и $F_1$ score для следующий моделей:
# * BERT-base-cased
# * BERT-base-uncased
# * BERT-large-cased
# * BERT-large-uncased

# %% [markdown]
# #### BERT-base-cased

# %% [markdown]
# Графики обучения:
# (Метрика recall посчитана без учёта класса 'other', отвечающего за неличные сущности).

# %%
t_reader = TensorBoardReader(Path(bert_base_model_config["log_dir"]) / Path("lightning_logs"))
t_reader.plot_tensorboard_graphics(0)

# %% [markdown]
# Из обучения взята модель с лучшим показателем в метрике recall без учёта класса 'other'. Посмотрим на её метрики на валидационных данных.

# %%
# Data processing
test_dataset = get_ner_dataset(data_type=i2b2_2014_data_config['val_data_type'],
                               path_to_folder=i2b2_2014_data_config["validate_data_path"],
                               is_uncased=False,
                               pretrained_tokenizer=i2b2_2014_data_config["pretrained_tokenizer_path"],
                               max_length=i2b2_2014_data_config["max_token_number"],
                               eq_max_padding=i2b2_2014_data_config["eq_max_padding"])
test_dataloader = DataLoader(test_dataset, shuffle=False,
                             batch_size=i2b2_2014_data_config["batch_size"],
                             collate_fn=test_dataset.get_collate_fn())
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (653 > 512). Running this sequence through the model will result in indexing errors

# %%
# Model initialisation
path_to_checkpoint = t_reader.get_ckpt_path()
ner_model = PretrainedBertNER.load_from_checkpoint(path_to_checkpoint)
print(ner_model)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# PretrainedBertNER(
#   (model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (head): Sequential(
#     (0): Linear(in_features=768, out_features=384, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=384, out_features=9, bias=True)
#   )
#   (criterion): CrossEntropyLoss()
#   (train_recall): MulticlassRecall()
#   (train_precision): MulticlassPrecision()
#   (train_f1_score): MulticlassF1Score()
#   (val_recall): MulticlassRecall()
#   (val_precision): MulticlassPrecision()
#   (val_f1_score): MulticlassF1Score()
# )

# %%
# Testing
trainer_args = {
    "accelerator": "gpu",
    "logger": False
}
trainer = pl.Trainer(**trainer_args, enable_progress_bar=True)
trainer.test(ner_model, test_dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_recall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_precision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_f1', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          test_f1            0.9942045211791992
#      test_precision         0.9942045211791992
#        test_recall          0.9913195967674255
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_recall': 0.9913195967674255,
#   'test_precision': 0.9942045211791992,
#   'test_f1': 0.9942045211791992}]

# %%
# Print metrics
stats = Statistics(ner_model, test_dataloader)
print(stats.get_classification_report())
stats.plot_confusion_matrix()
stats.print_random_failed_predictions()
# Out:
#               precision    recall  f1-score   support
#
#         NAME     0.9733    0.9901    0.9816      3023
#   PROFESSION     0.0000    0.0000    0.0000        13
#     LOCATION     0.9300    0.9789    0.9538      2227
#          AGE     0.9913    0.9942    0.9927       343
#         DATE     0.9984    0.9972    0.9978      5715
#           ID     0.9923    0.9967    0.9945      1804
#      CONTACT     0.9948    0.9914    0.9931       584
#            O     0.9688    0.9953    0.9819     37538
#
#    micro avg     0.9718    0.9942    0.9829     51247
#    macro avg     0.8561    0.8680    0.8619     51247
# weighted avg     0.9717    0.9942    0.9828     51247
# Wrongly predicted examples:
# _____ Record 191-01 _____
# | Sentence:    | record | date | : | 2091 | -    | 08   | -    | 02   | chief | complaint | aaa      | history | of | present | illness | the | patient | is | a | 66  | y | . | o | . | male | with | aaa | who | is | scheduled | for | endovascular | repair | of | aaa | on | august | 06   | ,    | 2091 | with | dr | . | carter | horne | . | pt | . | was | having | problems | with | tingling | in | right | foot | and | ankle | . | he | went | to | his | pcp | who | as | part | of | the | workup | did | and | ultrasound | and | pt | . | aaa | was | discovered | . | pt | . | had | no | symptoms | then | , | and | has | no | symptoms | now | , |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O     | O         | O        | O       | O  | O       | O       | O   | O       | O  | O | AGE | O | O | O | O | O    | O    | O   | O   | O  | O         | O   | O            | O      | O  | O   | O  | DATE   | DATE | DATE | DATE | O    | O  | O | NAME   | NAME  | O | O  | O | O   | O      | O        | O    | O        | O  | O     | O    | O   | O     | O | O  | O    | O  | O   | O   | O   | O  | O    | O  | O   | O      | O   | O   | O          | O   | O  | O | O   | O   | O          | O | O  | O | O   | O  | O        | O    | O | O   | O   | O  | O        | O   | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O     | O         | LOCATION | O       | O  | O       | O       | O   | O       | O  | O | AGE | O | O | O | O | O    | O    | O   | O   | O  | O         | O   | O            | O      | O  | O   | O  | DATE   | DATE | DATE | DATE | O    | O  | O | NAME   | NAME  | O | O  | O | O   | O      | O        | O    | O        | O  | O     | O    | O   | O     | O | O  | O    | O  | O   | O   | O   | O  | O    | O  | O   | O      | O   | O   | O          | O   | O  | O | O   | O   | O          | O | O  | O | O   | O  | O        | O    | O | O   | O   | O  | O        | O   | O |
# _____ Record 130-01 _____
# | Sentence:    | record | date | : | 2084 | -    | 10   | -    | 19   | mae  | paul     | lmc      | # | 100 | -  | 57 | -  | 08 | lmc      | surgery  | clinic   | note | october | 19   | ,    | 2084 | cc | : | consult | for | hemorrhoids | . | hpi | : | this | is | a | 73  | - | year | - | old | female | . | five | - | to | six | - | year | history | constant | anal | protrusion | and | bloody | discharge | and | mucus | nearly | constantly | ( | wears | a | pad | ) | . | no | anal | pain | . | usually | has | 1 | - | 2 | bms | a | day | , | solid | or | liquid | ( | her | chronic | pattern | ) | . |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME | NAME     | LOCATION | O | ID  | ID | ID | ID | ID | LOCATION | O        | O        | O    | DATE    | DATE | DATE | DATE | O  | O | O       | O   | O           | O | O   | O | O    | O  | O | AGE | O | O    | O | O   | O      | O | O    | O | O  | O   | O | O    | O       | O        | O    | O          | O   | O      | O         | O   | O     | O      | O          | O | O     | O | O   | O | O | O  | O    | O    | O | O       | O   | O | O | O | O   | O | O   | O | O     | O  | O      | O | O   | O       | O       | O | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME | LOCATION | LOCATION | O | ID  | ID | ID | ID | ID | LOCATION | LOCATION | LOCATION | O    | DATE    | DATE | DATE | DATE | O  | O | O       | O   | O           | O | O   | O | O    | O  | O | AGE | O | O    | O | O   | O      | O | O    | O | O  | O   | O | O    | O       | O        | O    | O          | O   | O      | O         | O   | O     | O      | O          | O | O     | O | O   | O | O | O  | O    | O    | O | O       | O   | O | O | O | O   | O | O   | O | O     | O  | O      | O | O   | O       | O       | O | O |
# _____ Record 310-04 _____
# | Sentence:    | record | date | : | 2075 | -    | 03   | -    | 03   | id | consult | note | patient | name | : | vincent | ware | mrn | : | 98044905 | date | of | admission | : | 3    | /    | 02   | /    | 75   | date | of | consult | : | 3    | /    | 03   | /    | 75   | id | attending | : | haney | id | fellow | : | riddle | service | attending | : | vann | reason | for | consult | : | cough | , | dyspnea | , | fevers | s | / | p | hsct | off | immune | suppression | hpi | : | mr | . | ware | is | a | 67  | - | year | - | old | man | with | a | history | non | - | hodgkins |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O  | O       | O    | O       | O    | O | NAME    | NAME | O   | O | ID       | O    | O  | O         | O | DATE | DATE | DATE | DATE | DATE | O    | O  | O       | O | DATE | DATE | DATE | DATE | DATE | O  | O         | O | NAME  | O  | O      | O | NAME   | O       | O         | O | NAME | O      | O   | O       | O | O     | O | O       | O | O      | O | O | O | O    | O   | O      | O           | O   | O | O  | O | NAME | O  | O | AGE | O | O    | O | O   | O   | O    | O | O       | O   | O | O        |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O  | O       | O    | O       | O    | O | NAME    | NAME | O   | O | ID       | O    | O  | O         | O | DATE | DATE | DATE | DATE | DATE | O    | O  | O       | O | DATE | DATE | DATE | DATE | DATE | O  | O         | O | NAME  | O  | O      | O | O      | O       | O         | O | NAME | O      | O   | O       | O | O     | O | O       | O | O      | O | O | O | O    | O   | O      | O           | O   | O | O  | O | NAME | O  | O | AGE | O | O    | O | O   | O   | O    | O | O       | O   | O | O        |
# _____ Record 387-04 _____
# | Sentence:    | record | date | : | 2084 | -    | 06   | -    | 15   | patient | : | patrick | gillespie | mrn | : | 2571454 | admit | date | : | 6    | /    | 13   | /    | 84   | transfer | date | : | 6    | /    | 15   | /    | 84   | attn | : | wright | reason | for | admission | / | transfer | : | aflutter | starting | on | sotalol | hpi | please | see | admission | note | for | full | details | . | in | brief | , | this | is | a | 54  | y | / | o | m | hx | neurofibromatosis | , | hodgkin | ' | s | lymphoma | s | / | p | chemo | / |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O       | O | NAME    | NAME      | O   | O | ID      | O     | O    | O | DATE | DATE | DATE | DATE | DATE | O        | O    | O | DATE | DATE | DATE | DATE | DATE | O    | O | NAME   | O      | O   | O         | O | O        | O | O        | O        | O  | O       | O   | O      | O   | O         | O    | O   | O    | O       | O | O  | O     | O | O    | O  | O | AGE | O | O | O | O | O  | O                 | O | O       | O | O | O        | O | O | O | O     | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O       | O | NAME    | NAME      | O   | O | ID      | O     | O    | O | DATE | DATE | DATE | DATE | DATE | O        | O    | O | DATE | DATE | DATE | DATE | DATE | O    | O | NAME   | O      | O   | O         | O | O        | O | NAME     | O        | O  | O       | O   | O      | O   | O         | O    | O   | O    | O       | O | O  | O     | O | O    | O  | O | AGE | O | O | O | O | O  | O                 | O | O       | O | O | O        | O | O | O | O     | O |
# _____ Record 380-03 _____
# | Sentence:    | record | date | : | 2070 | -    | 08   | -    | 28   | cc | : | follow | - | up | hpi | : | 75  | - | year | - | old | woman | with | a | history | of | hypertension | , | diabetes | , | and | hypercholesterolemia | and | paf | with | a | prior | stroke | ( | 2067 | ) | who | subsequently | was | admitted | to | the | och      | again | for | sdh      | with | supratherapeutic | inr | in | 2068 | . | she | has | a | prolonged | hospital | course | as | well | as | rehab | stay | and | now | returns | having | made | significant | recovery | . | her | peg | was | pulled | - | out | in |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O  | O | O      | O | O  | O   | O | AGE | O | O    | O | O   | O     | O    | O | O       | O  | O            | O | O        | O | O   | O                    | O   | O   | O    | O | O     | O      | O | DATE | O | O   | O            | O   | O        | O  | O   | LOCATION | O     | O   | O        | O    | O                | O   | O  | DATE | O | O   | O   | O | O         | O        | O      | O  | O    | O  | O     | O    | O   | O   | O       | O      | O    | O           | O        | O | O   | O   | O   | O      | O | O   | O  |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O  | O | O      | O | O  | O   | O | AGE | O | O    | O | O   | O     | O    | O | O       | O  | O            | O | O        | O | O   | O                    | O   | O   | O    | O | O     | O      | O | DATE | O | O   | O            | O   | O        | O  | O   | LOCATION | O     | O   | LOCATION | O    | O                | O   | O  | DATE | O | O   | O   | O | O         | O        | O      | O  | O    | O  | O     | O    | O   | O   | O       | O      | O    | O           | O        | O | O   | O   | O   | O      | O | O   | O  |

# %% [markdown]
# #### BERT-base-uncased

# %% [markdown]
# Графики обучения:
# (Метрика recall посчитана без учёта класса 'other', отвечающего за неличные сущности).

# %%
t_reader = TensorBoardReader(Path(bert_base_model_config["log_dir"]) / Path("lightning_logs"))
t_reader.plot_tensorboard_graphics(1)

# %% [markdown]
# Из обучения взята модель с лучшим показателем в метрике recall без учёта класса 'other'. Посмотрим на её метрики на валидационных данных.

# %%
# Data processing
test_dataset = get_ner_dataset(data_type=i2b2_2014_data_config['val_data_type'],
                               path_to_folder=i2b2_2014_data_config["validate_data_path"],
                               is_uncased=True,
                               pretrained_tokenizer=i2b2_2014_data_config["pretrained_tokenizer_path"],
                               max_length=i2b2_2014_data_config["max_token_number"],
                               eq_max_padding=i2b2_2014_data_config["eq_max_padding"])
test_dataloader = DataLoader(test_dataset, shuffle=False,
                             batch_size=i2b2_2014_data_config["batch_size"],
                             collate_fn=test_dataset.get_collate_fn())
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (653 > 512). Running this sequence through the model will result in indexing errors

# %%
# Model initialisation
path_to_checkpoint = t_reader.get_ckpt_path()
ner_model = PretrainedBertNER.load_from_checkpoint(path_to_checkpoint)
print(ner_model)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# PretrainedBertNER(
#   (model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (head): Sequential(
#     (0): Linear(in_features=768, out_features=384, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=384, out_features=9, bias=True)
#   )
#   (criterion): CrossEntropyLoss()
#   (train_recall): MulticlassRecall()
#   (train_precision): MulticlassPrecision()
#   (train_f1_score): MulticlassF1Score()
#   (val_recall): MulticlassRecall()
#   (val_precision): MulticlassPrecision()
#   (val_f1_score): MulticlassF1Score()
# )

# %%
# Testing
trainer_args = {
    "accelerator": "gpu",
    "logger": False
}
trainer = pl.Trainer(**trainer_args, enable_progress_bar=True)
trainer.test(ner_model, test_dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_recall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_precision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_f1', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          test_f1            0.9942045211791992
#      test_precision         0.9942045211791992
#        test_recall          0.9913195967674255
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_recall': 0.9913195967674255,
#   'test_precision': 0.9942045211791992,
#   'test_f1': 0.9942045211791992}]

# %%
# Print metrics
stats = Statistics(ner_model, test_dataloader)
print(stats.get_classification_report())
stats.plot_confusion_matrix()
stats.print_random_failed_predictions()
# Out:
#               precision    recall  f1-score   support
#
#         NAME     0.9733    0.9901    0.9816      3023
#   PROFESSION     0.0000    0.0000    0.0000        13
#     LOCATION     0.9300    0.9789    0.9538      2227
#          AGE     0.9913    0.9942    0.9927       343
#         DATE     0.9984    0.9972    0.9978      5715
#           ID     0.9923    0.9967    0.9945      1804
#      CONTACT     0.9948    0.9914    0.9931       584
#            O     0.9688    0.9953    0.9819     37538
#
#    micro avg     0.9718    0.9942    0.9829     51247
#    macro avg     0.8561    0.8680    0.8619     51247
# weighted avg     0.9717    0.9942    0.9828     51247
# Wrongly predicted examples:
# _____ Record 374-03 _____
# | Sentence:    | record | date | : | 2133 | -    | 01   | -    | 22   | wise | ,    | willa | internal | medicine | associates | , | suite | 7 | bayne    | -        | jones    | army     | community | hospital | , | 0th | floor | , | noom | 038 | hayti    | ,        | de       | , | 36349    | -        | 2179     | re | : | norma | mckee | 01   | /    | 22   | /    | 2133 | admission | note | ima | consult | note | covering | for | dr | robert | xenakis | cc | 57  | yo | with | multiple | medical | , | psychiatric | problems | admitted | with | recurrent | sbo | and | acute | renal | failure | hpi | pt | has | hx | tab | / | bso | , |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME | NAME | NAME  | O        | O        | O          | O | O     | O | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION  | LOCATION | O | O   | O     | O | O    | O   | LOCATION | O        | LOCATION | O | LOCATION | LOCATION | LOCATION | O  | O | NAME  | NAME  | DATE | DATE | DATE | DATE | DATE | O         | O    | O   | O       | O    | O        | O   | O  | NAME   | NAME    | O  | AGE | O  | O    | O        | O       | O | O           | O        | O        | O    | O         | O   | O   | O     | O     | O       | O   | O  | O   | O  | O   | O | O   | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME | NAME | NAME  | O        | O        | O          | O | O     | O | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION  | LOCATION | O | O   | O     | O | O    | O   | LOCATION | LOCATION | LOCATION | O | LOCATION | LOCATION | LOCATION | O  | O | NAME  | NAME  | DATE | DATE | DATE | DATE | DATE | O         | O    | O   | O       | O    | O        | O   | O  | NAME   | NAME    | O  | AGE | O  | O    | O        | O       | O | O           | O        | O        | O    | O         | O   | O   | O     | O     | O       | O   | O  | O   | O  | O   | O | O   | O |
# _____ Record 197-04 _____
# | Sentence:    | record | date | : | 2098 | -    | 12   | -    | 10   | 059 | -  | 57 | -  | 26 | emery | ,    | donn | december | 10   | ,    | 2098 | endocrine | / | diabetes | present | illness | : | asked | to | see | this | 89  | year | old | patient | of | drs | . | pina | and  | keefe | , | admitted | with | an | acute | exacerbation | of | congestive | heart | failure | in | the | context | of | severe | aortic | stenosis | and | less | attention | to | diet | at | the | time | of | his | wife | ' | s | death | last | week | . | he | is | approaching | probable | avr | and | ? |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | ID  | ID | ID | ID | ID | NAME  | NAME | NAME | DATE     | DATE | DATE | DATE | O         | O | O        | O       | O       | O | O     | O  | O   | O    | AGE | O    | O   | O       | O  | O   | O | NAME | O    | NAME  | O | O        | O    | O  | O     | O            | O  | O          | O     | O       | O  | O   | O       | O  | O      | O      | O        | O   | O    | O         | O  | O    | O  | O   | O    | O  | O   | O    | O | O | O     | O    | O    | O | O  | O  | O           | O        | O   | O   | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | ID  | ID | ID | ID | ID | NAME  | NAME | NAME | DATE     | DATE | DATE | DATE | O         | O | O        | O       | O       | O | O     | O  | O   | O    | AGE | O    | O   | O       | O  | O   | O | NAME | NAME | NAME  | O | O        | O    | O  | O     | O            | O  | O          | O     | O       | O  | O   | O       | O  | O      | O      | O        | O   | O    | O         | O  | O    | O  | O   | O    | O  | O   | O    | O | O | O     | O    | O    | O | O  | O  | O           | O        | O   | O   | O |
# _____ Record 347-02 _____
# | Sentence:    | record | date | : | 2095 | -    | 12   | -    | 09   | cookson  | memorial | home     | internal | medicine | room | 960      | 87       | wellesley | rd       | darling | ,    | betty | seattle  | , | sc       | 84126    | 78567873 | (       | 121     | )       | 537     | -       | 3484    | 12   | /    | 09   | /    | 95   | chief | complaint | : | multiple | acute | and | chronic | medical | issues | , | including | subacute | weight | loss | . | identification | : | this | is | my | first | medical | visit | with | this | 75  | - | year | - | old | woman | with | multiple | recent | hospitalizations | . | history | of | present | illness | : | she | has | a | long | history | of | severe |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | LOCATION | LOCATION | O        | O        | O    | O        | LOCATION | LOCATION  | LOCATION | NAME    | NAME | NAME  | LOCATION | O | LOCATION | LOCATION | ID       | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O     | O         | O | O        | O     | O   | O       | O       | O      | O | O         | O        | O      | O    | O | O              | O | O    | O  | O  | O     | O       | O     | O    | O    | AGE | O | O    | O | O   | O     | O    | O        | O      | O                | O | O       | O  | O       | O       | O | O   | O   | O | O    | O       | O  | O      |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | LOCATION | LOCATION | O        | O        | O    | LOCATION | LOCATION | LOCATION  | LOCATION | NAME    | NAME | NAME  | LOCATION | O | LOCATION | LOCATION | ID       | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O     | O         | O | O        | O     | O   | O       | O       | O      | O | O         | O        | O      | O    | O | O              | O | O    | O  | O  | O     | O       | O     | O    | O    | AGE | O | O    | O | O   | O     | O    | O        | O      | O                | O | O       | O  | O       | O       | O | O   | O   | O | O    | O       | O  | O      |
# _____ Record 378-02 _____
# | Sentence:    | record | date | : | 2063 | -    | 12   | -    | 13   | name | : | umphrey | ,    | tammy | mrn | : | 0942207 | the | patient | is | here | as | a | walk | - | in | . | her | spouse | is | present | . | patient | says | she | is | status | post | a | fall | this | past | monday | at | home | . | says | that | she | seems | to | have | lost | her | balance | while | opening | a | door | at | home | . | denies | prodromal | symptoms | including | shortness | of | breath | , | dizziness | , | or | palpitations | . | there | was | no | loss | of | consciousness | . | patient | was | seen | in | the | emergency |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O    | O | NAME    | NAME | NAME  | O   | O | ID      | O   | O       | O  | O    | O  | O | O    | O | O  | O | O   | O      | O  | O       | O | O       | O    | O   | O  | O      | O    | O | O    | O    | O    | DATE   | O  | O    | O | O    | O    | O   | O     | O  | O    | O    | O   | O       | O     | O       | O | O    | O  | O    | O | O      | O         | O        | O         | O         | O  | O      | O | O         | O | O  | O            | O | O     | O   | O  | O    | O  | O             | O | O       | O   | O    | O  | O   | O         |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O    | O | NAME    | NAME | NAME  | O   | O | ID      | O   | O       | O  | O    | O  | O | O    | O | O  | O | O   | O      | O  | O       | O | O       | O    | O   | O  | O      | O    | O | O    | O    | O    | O      | O  | O    | O | O    | O    | O   | O     | O  | O    | O    | O   | O       | O     | O       | O | O    | O  | O    | O | O      | O         | O        | O         | O         | O  | O      | O | O         | O | O  | O            | O | O     | O   | O  | O    | O  | O             | O | O       | O   | O    | O  | O   | O         |
# _____ Record 375-04 _____
# | Sentence:    | record | date | : | 2158 | -    | 06   | -    | 08   | - | - | - | - | - | - | - | - | - | - | - | - | - | parkinson | ' | s | clinic | trumbull | memorial | hospital | -        | corcoran | district | hospital | (        | 315      | )       | 433     | -       | 0039    | office | visit | chief | complaint | : | increased | falling | history | of | present | illness | : | c | / | o | increased | falling | . | his | legs | buckling | underneath | him | . | he | has | occasional | dizzyness | . | denies | angino | , | or | sob | . | he | does | not | use | a | walker | . | he | arrived | today | in | a | wheel | chair | . | they | both |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O | O | O | O | O | O | O | O | O | O | O | O | O | O         | O | O | O      | LOCATION | LOCATION | LOCATION | O        | LOCATION | LOCATION | LOCATION | CONTACT  | CONTACT  | CONTACT | CONTACT | CONTACT | CONTACT | O      | O     | O     | O         | O | O         | O       | O       | O  | O       | O       | O | O | O | O | O         | O       | O | O   | O    | O        | O          | O   | O | O  | O   | O          | O         | O | O      | O      | O | O  | O   | O | O  | O    | O   | O   | O | O      | O | O  | O       | O     | O  | O | O     | O     | O | O    | O    |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O | O | O | O | O | O | O | O | O | O | O | O | O | O         | O | O | O      | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | CONTACT | CONTACT | CONTACT | CONTACT | O      | O     | O     | O         | O | O         | O       | O       | O  | O       | O       | O | O | O | O | O         | O       | O | O   | O    | O        | O          | O   | O | O  | O   | O          | O         | O | O      | O      | O | O  | O   | O | O  | O    | O   | O   | O | O      | O | O  | O       | O     | O  | O | O     | O     | O | O    | O    |

# %% [markdown]
# #### BERT-large-cased

# %% [markdown]
# Графики обучения:
# (Метрика recall посчитана без учёта класса 'other', отвечающего за неличные сущности).

# %%
t_reader = TensorBoardReader(Path(bert_large_model_config["log_dir"]) / Path("lightning_logs"))
t_reader.plot_tensorboard_graphics(0)

# %% [markdown]
# Из обучения взята модель с лучшим показателем в метрике recall без учёта класса 'other'. Посмотрим на её метрики на валидационных данных.

# %%
# Data processing
test_dataset = get_ner_dataset(data_type=i2b2_2014_data_config['val_data_type'],
                               path_to_folder=i2b2_2014_data_config["validate_data_path"],
                               is_uncased=False,
                               pretrained_tokenizer=i2b2_2014_data_config["pretrained_tokenizer_path"],
                               max_length=i2b2_2014_data_config["max_token_number"],
                               eq_max_padding=i2b2_2014_data_config["eq_max_padding"])
test_dataloader = DataLoader(test_dataset, shuffle=False,
                             batch_size=i2b2_2014_data_config["batch_size"],
                             collate_fn=test_dataset.get_collate_fn())
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (653 > 512). Running this sequence through the model will result in indexing errors

# %%
# Model initialisation
path_to_checkpoint = t_reader.get_ckpt_path()
ner_model = PretrainedBertNER.load_from_checkpoint(path_to_checkpoint)
print(ner_model)
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# PretrainedBertNER(
#   (model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 1024, padding_idx=0)
#       (position_embeddings): Embedding(512, 1024)
#       (token_type_embeddings): Embedding(2, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-23): 24 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=1024, out_features=1024, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (head): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=9, bias=True)
#   )
#   (criterion): CrossEntropyLoss()
#   (train_recall): MulticlassRecall()
#   (train_precision): MulticlassPrecision()
#   (train_f1_score): MulticlassF1Score()
#   (val_recall): MulticlassRecall()
#   (val_precision): MulticlassPrecision()
#   (val_f1_score): MulticlassF1Score()
# )

# %%
# Testing
trainer_args = {
    "accelerator": "gpu",
    "logger": False
}
trainer = pl.Trainer(**trainer_args, enable_progress_bar=True)
trainer.test(ner_model, test_dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_recall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_precision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_f1', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          test_f1            0.9950436353683472
#      test_precision         0.9950436353683472
#        test_recall          0.9922678470611572
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_recall': 0.9922678470611572,
#   'test_precision': 0.9950436353683472,
#   'test_f1': 0.9950436353683472}]

# %%
# Print metrics
stats = Statistics(ner_model, test_dataloader)
print(stats.get_classification_report())
stats.plot_confusion_matrix()
stats.print_random_failed_predictions()
# Out:
#               precision    recall  f1-score   support
#
#         NAME     0.9727    0.9904    0.9815      3023
#   PROFESSION     1.0000    0.3077    0.4706        13
#     LOCATION     0.9454    0.9793    0.9621      2227
#          AGE     0.9552    0.9942    0.9743       343
#         DATE     0.9983    0.9984    0.9983      5715
#           ID     0.9934    0.9956    0.9945      1804
#      CONTACT     0.9748    0.9949    0.9847       584
#            O     0.9696    0.9961    0.9827     37538
#
#    micro avg     0.9726    0.9950    0.9837     51247
#    macro avg     0.9762    0.9071    0.9186     51247
# weighted avg     0.9727    0.9950    0.9837     51247
# Wrongly predicted examples:
# _____ Record 167-02 _____
# | Sentence:    | record | date | : | 2078 | -    | 11   | -    | 10   | november | 10   | ,    | 2078 | tanae | shirley | , | m | . | d | . | obstetrics | callaway | district | hospital | 97       | jared    | circle   | falmouth | al       | 98623    | re | : | irene | yarbrough | cdh      | # | 810 | 86 | 43 | 7  | dear | dr | . | shirley | : | thank | you | for | referring | irene | yarbrough | for | evaluation | of | her | atrial | fibrillation | . | mrs | . | yarbrough | is | 55  | years | old | . | over | the | past | year | she | had | had |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | DATE     | DATE | DATE | DATE | NAME  | NAME    | O | O | O | O | O | O          | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | O  | O | NAME  | NAME      | LOCATION | O | ID  | ID | ID | ID | O    | O  | O | NAME    | O | O     | O   | O   | O         | NAME  | NAME      | O   | O          | O  | O   | O      | O            | O | O   | O | NAME      | O  | AGE | O     | O   | O | O    | O   | O    | O    | O   | O   | O   |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | DATE     | DATE | DATE | DATE | NAME  | NAME    | O | O | O | O | O | O          | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | O  | O | NAME  | NAME      | LOCATION | O | ID  | ID | ID | ID | O    | O  | O | NAME    | O | O     | O   | O   | O         | NAME  | NAME      | O   | O          | O  | O   | O      | O            | O | O   | O | NAME      | O  | AGE | O     | O   | O | O    | O   | O    | O    | O   | O   | O   |
# _____ Record 388-05 _____
# | Sentence:    | record | date | : | 2081 | -    | 09   | -    | 06   | 09   | /    | 06   | /    | 81   | follow | up | after | long | absence | . | pt | was | seen | last | week | by | dr | . | anderson | and | prior | to | that | she | was | at | chesterfield | ed       | and | prior | to | that | her | son | reports | that | she | had | been | in | ghanna   | . | i | suspect | she | has | been | under | someone | else | ' | s | care | since | i | never | prescribed | glyburide | , | actos | and | insulin | . | the | last | time | i | saw | her | in | january | i | discontinued | metformin | because | of | gi | intolerance | and | her |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | DATE | DATE | DATE | DATE | DATE | O      | O  | O     | O    | O       | O | O  | O   | O    | O    | O    | O  | O  | O | NAME     | O   | O     | O  | O    | O   | O   | O  | LOCATION     | O        | O   | O     | O  | O    | O   | O   | O       | O    | O   | O   | O    | O  | LOCATION | O | O | O       | O   | O   | O    | O     | O       | O    | O | O | O    | O     | O | O     | O          | O         | O | O     | O   | O       | O | O   | O    | O    | O | O   | O   | O  | DATE    | O | O            | O         | O       | O  | O  | O           | O   | O   |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | DATE | DATE | DATE | DATE | DATE | O      | O  | O     | O    | O       | O | O  | O   | O    | O    | O    | O  | O  | O | NAME     | O   | O     | O  | O    | O   | O   | O  | LOCATION     | LOCATION | O   | O     | O  | O    | O   | O   | O       | O    | O   | O   | O    | O  | LOCATION | O | O | O       | O   | O   | O    | O     | O       | O    | O | O | O    | O     | O | O     | O          | O         | O | O     | O   | O       | O | O   | O    | O    | O | O   | O   | O  | DATE    | O | O            | O         | O       | O  | O  | O           | O   | O   |
# _____ Record 374-03 _____
# | Sentence:    | record | date | : | 2133 | -    | 01   | -    | 22   | wise | ,    | willa | internal | medicine | associates | , | suite | 7 | bayne    | -        | jones    | army     | community | hospital | , | 0th | floor | , | noom | 038 | hayti    | , | de       | , | 36349    | -        | 2179     | re | : | norma | mckee | 01   | /    | 22   | /    | 2133 | admission | note | ima | consult | note | covering | for | dr | robert | xenakis | cc | 57  | yo | with | multiple | medical | , | psychiatric | problems | admitted | with | recurrent | sbo | and | acute | renal | failure | hpi | pt | has | hx | tab | / | bso | , |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME | NAME | NAME  | O        | O        | O          | O | O     | O | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION  | LOCATION | O | O   | O     | O | O    | O   | LOCATION | O | LOCATION | O | LOCATION | LOCATION | LOCATION | O  | O | NAME  | NAME  | DATE | DATE | DATE | DATE | DATE | O         | O    | O   | O       | O    | O        | O   | O  | NAME   | NAME    | O  | AGE | O  | O    | O        | O       | O | O           | O        | O        | O    | O         | O   | O   | O     | O     | O       | O   | O  | O   | O  | O   | O | O   | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME | NAME | NAME  | O        | O        | O          | O | O     | O | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION  | LOCATION | O | O   | O     | O | O    | O   | LOCATION | O | LOCATION | O | LOCATION | LOCATION | LOCATION | O  | O | NAME  | NAME  | DATE | DATE | DATE | DATE | DATE | O         | O    | O   | O       | O    | O        | O   | O  | NAME   | NAME    | O  | AGE | O  | O    | O        | O       | O | O           | O        | O        | O    | O         | O   | O   | O     | O     | O       | O   | O  | O   | O  | O   | O | O   | O |
# _____ Record 193-05 _____
# | Sentence:    | record | date | : | 2096 | -    | 03   | -    | 18   | foust | ,    | fay  | 50294530 | 03   | /    | 18   | /    | 2096 | bethany  | downs    | , | md       | linden   | internal | medicine | associates | 08       | kent     | lane     | , | a1       | -        | 49       | union    | city     | , | mo       | 43733    | 1 | . | hungary  | native | and | retired | health     | policy     | consultant | . | daughter | and | son | - | in | - | law | were | medical | school | classmates | of | dr | . | downs | . | 2 | . | alpha | thalassemia | trait | . | 12   | /    | 95   | hematocrit | 34 | . | 7 | , | mcv | 66 | . | 1 | , | rdw | 14 |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME  | NAME | NAME | ID       | DATE | DATE | DATE | DATE | DATE | NAME     | NAME     | O | O        | LOCATION | O        | O        | O          | LOCATION | LOCATION | LOCATION | O | O        | O        | O        | LOCATION | LOCATION | O | LOCATION | LOCATION | O | O | LOCATION | O      | O   | O       | PROFESSION | PROFESSION | PROFESSION | O | O        | O   | O   | O | O  | O | O   | O    | O       | O      | O          | O  | O  | O | NAME  | O | O | O | O     | O           | O     | O | DATE | DATE | DATE | O          | O  | O | O | O | O   | O  | O | O | O | O   | O  |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | NAME  | NAME | NAME | ID       | DATE | DATE | DATE | DATE | DATE | LOCATION | LOCATION | O | LOCATION | LOCATION | O        | O        | O          | LOCATION | LOCATION | LOCATION | O | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | O | LOCATION | LOCATION | O | O | LOCATION | O      | O   | O       | O          | O          | O          | O | O        | O   | O   | O | O  | O | O   | O    | O       | O      | O          | O  | O  | O | NAME  | O | O | O | O     | O           | O     | O | DATE | DATE | DATE | O          | O  | O | O | O | O   | O  | O | O | O | O   | O  |
# _____ Record 313-02 _____
# | Sentence:    | record | date | : | 2066 | -    | 10   | -    | 08   | patient | name | : | rutledge | ,    | eva  | [ | mrn | : | 37947241zgj | ] | date | of | visit | : | 10   | /    | 08   | /    | 2066 | promptcare | ima      | clinic   | note | mrs | . | rutledge | is | a | former | patient | of | dr | . | xia  | ' | s | who | comes | in | today | to | establish | a | new | pcp | and | for | follow | - | up | of | her | hypertension | , | diabetes | , | chronic | renal | insufficiency | ( | baseline | creatinine | 2 | . | 2 | ) |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O       | O    | O | NAME     | NAME | NAME | O | O   | O | ID          | O | O    | O  | O     | O | DATE | DATE | DATE | DATE | DATE | LOCATION   | O        | O        | O    | O   | O | NAME     | O  | O | O      | O       | O  | O  | O | NAME | O | O | O   | O     | O  | O     | O  | O         | O | O   | O   | O   | O   | O      | O | O  | O  | O   | O            | O | O        | O | O       | O     | O             | O | O        | O          | O | O | O | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O       | O    | O | NAME     | NAME | NAME | O | O   | O | ID          | O | O    | O  | O     | O | DATE | DATE | DATE | DATE | DATE | LOCATION   | LOCATION | LOCATION | O    | O   | O | NAME     | O  | O | O      | O       | O  | O  | O | NAME | O | O | O   | O     | O  | O     | O  | O         | O | O   | O   | O   | O   | O      | O | O  | O  | O   | O            | O | O        | O | O       | O     | O             | O | O        | O          | O | O | O | O |

# %% [markdown]
# #### BERT-base-cased

# %% [markdown]
# Графики обучения:
# (Метрика recall посчитана без учёта класса 'other', отвечающего за неличные сущности).

# %%
t_reader = TensorBoardReader(Path(bert_large_model_config["log_dir"]) / Path("lightning_logs"))
t_reader.plot_tensorboard_graphics(1)

# %% [markdown]
# Из обучения взята модель с лучшим показателем в метрике recall без учёта класса 'other'. Посмотрим на её метрики на валидационных данных.

# %%
# Data processing
test_dataset = get_ner_dataset(data_type=i2b2_2014_data_config['val_data_type'],
                               path_to_folder=i2b2_2014_data_config["validate_data_path"],
                               is_uncased=True,
                               pretrained_tokenizer=i2b2_2014_data_config["pretrained_tokenizer_path"],
                               max_length=i2b2_2014_data_config["max_token_number"],
                               eq_max_padding=i2b2_2014_data_config["eq_max_padding"])
test_dataloader = DataLoader(test_dataset, shuffle=False,
                             batch_size=i2b2_2014_data_config["batch_size"],
                             collate_fn=test_dataset.get_collate_fn())
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (653 > 512). Running this sequence through the model will result in indexing errors

# %%
# Model initialisation
path_to_checkpoint = t_reader.get_ckpt_path()
ner_model = PretrainedBertNER.load_from_checkpoint(path_to_checkpoint)
print(ner_model)
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# PretrainedBertNER(
#   (model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 1024, padding_idx=0)
#       (position_embeddings): Embedding(512, 1024)
#       (token_type_embeddings): Embedding(2, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-23): 24 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=1024, out_features=1024, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (head): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=9, bias=True)
#   )
#   (criterion): CrossEntropyLoss()
#   (train_recall): MulticlassRecall()
#   (train_precision): MulticlassPrecision()
#   (train_f1_score): MulticlassF1Score()
#   (val_recall): MulticlassRecall()
#   (val_precision): MulticlassPrecision()
#   (val_f1_score): MulticlassF1Score()
# )

# %%
# Testing
trainer_args = {
    "accelerator": "gpu",
    "logger": False
}
trainer = pl.Trainer(**trainer_args, enable_progress_bar=True)
trainer.test(ner_model, test_dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_recall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_precision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_f1', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          test_f1            0.9950436353683472
#      test_precision         0.9950436353683472
#        test_recall          0.9922678470611572
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_recall': 0.9922678470611572,
#   'test_precision': 0.9950436353683472,
#   'test_f1': 0.9950436353683472}]

# %%
# Print metrics
stats = Statistics(ner_model, test_dataloader)
print(stats.get_classification_report())
stats.plot_confusion_matrix()
stats.print_random_failed_predictions()
# Out:
#               precision    recall  f1-score   support
#
#         NAME     0.9727    0.9904    0.9815      3023
#   PROFESSION     1.0000    0.3077    0.4706        13
#     LOCATION     0.9454    0.9793    0.9621      2227
#          AGE     0.9552    0.9942    0.9743       343
#         DATE     0.9983    0.9984    0.9983      5715
#           ID     0.9934    0.9956    0.9945      1804
#      CONTACT     0.9748    0.9949    0.9847       584
#            O     0.9696    0.9961    0.9827     37538
#
#    micro avg     0.9726    0.9950    0.9837     51247
#    macro avg     0.9762    0.9071    0.9186     51247
# weighted avg     0.9727    0.9950    0.9837     51247
# Wrongly predicted examples:
# _____ Record 167-04 _____
# | Sentence:    | record | date | : | 2090 | -    | 07   | -    | 12   | nightfloat | admit | note | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | name | : | yarbrough | ,    | irene | h    | mrn | : | 81086437 | date | of | admission | : | 7    | /    | 12   | /    | 90   | pcp | : | intern | : | gaines | attending | : | silva | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O          | O     | O    | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O    | O | NAME      | NAME | NAME  | NAME | O   | O | ID       | O    | O  | O         | O | DATE | DATE | DATE | DATE | DATE | O   | O | O      | O | NAME   | O         | O | NAME  | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION   | O     | O    | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O    | O | NAME      | NAME | NAME  | NAME | O   | O | ID       | O    | O  | O         | O | DATE | DATE | DATE | DATE | DATE | O   | O | O      | O | NAME   | O         | O | NAME  | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O | O |
# _____ Record 314-02 _____
# | Sentence:    | record | date | : | 2093 | -    | 06   | -    | 12   | dutch    | 19       | tamworth | place    | trent | ,    | shirley | galena   | , | mn       | 64864    | 99210914 | (       | 676     | )       | 312     | -       | 7662    | 06   | /    | 12   | /    | 93   | history | of | present | illness | : | ms | . | trent | is | 69  | , | a | pleasant | lady | who | is | now | a | widow | well | known | to | me | for | her | insulin | - | dependent | diabetes | and | her | poor | compliance | with | treatment | . | in | the | past | , | she | also | has | experienced | upper | gi | bleeding | due | to | a | peptic | ulcer | and | has | undergone |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | LOCATION | LOCATION | LOCATION | NAME  | NAME | NAME    | LOCATION | O | LOCATION | LOCATION | ID       | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O       | O  | O       | O       | O | O  | O | NAME  | O  | AGE | O | O | O        | O    | O   | O  | O   | O | O     | O    | O     | O  | O  | O   | O   | O       | O | O         | O        | O   | O   | O    | O          | O    | O         | O | O  | O   | O    | O | O   | O    | O   | O           | O     | O  | O        | O   | O  | O | O      | O     | O   | O   | O         |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | DATE     | LOCATION | LOCATION | LOCATION | NAME  | NAME | NAME    | LOCATION | O | LOCATION | LOCATION | ID       | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O       | O  | O       | O       | O | O  | O | NAME  | O  | AGE | O | O | O        | O    | O   | O  | O   | O | O     | O    | O     | O  | O  | O   | O   | O       | O | O         | O        | O   | O   | O    | O          | O    | O         | O | O  | O   | O    | O | O   | O    | O   | O           | O     | O  | O        | O   | O  | O | O      | O     | O   | O   | O         |
# _____ Record 211-02 _____
# | Sentence:    | record | date | : | 2093 | -    | 08   | -    | 19   | august | 19   | ,    | 2093 | john | ussery | , | m | . | d | . | worthington | - | internal | medicine | 80       | shattuck | street   | , | im | 270      | citrus   | ridge    | , | mt       | 43782    | re | : | russell | urban | wrh      | # | 4722064 | dear | dr | . | ussery | : | i | had | the | pleasure | of | seeing | mr | . | russell | urban | in | cardiology | clinic | today | . | as | you | know | , | mr | . | urban | is | a | very | pleasant | 50  | - | year | - | old | gentleman | who | on | july | 09   | ,    | 2093 |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | DATE   | DATE | DATE | DATE | NAME | NAME   | O | O | O | O | O | LOCATION    | O | O        | O        | LOCATION | LOCATION | LOCATION | O | O  | O        | LOCATION | LOCATION | O | LOCATION | LOCATION | O  | O | NAME    | NAME  | LOCATION | O | ID      | O    | O  | O | NAME   | O | O | O   | O   | O        | O  | O      | O  | O | NAME    | NAME  | O  | O          | O      | O     | O | O  | O   | O    | O | O  | O | NAME  | O  | O | O    | O        | AGE | O | O    | O | O   | O         | O   | O  | DATE | DATE | DATE | DATE |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | DATE   | DATE | DATE | DATE | NAME | NAME   | O | O | O | O | O | LOCATION    | O | O        | O        | LOCATION | LOCATION | LOCATION | O | O  | LOCATION | LOCATION | LOCATION | O | LOCATION | LOCATION | O  | O | NAME    | NAME  | LOCATION | O | ID      | O    | O  | O | NAME   | O | O | O   | O   | O        | O  | O      | O  | O | NAME    | NAME  | O  | O          | O      | O     | O | O  | O   | O    | O | O  | O | NAME  | O  | O | O    | O        | AGE | O | O    | O | O   | O         | O   | O  | DATE | DATE | DATE | DATE |
# _____ Record 168-03 _____
# | Sentence:    | record | date | : | 2073 | -    | 04   | -    | 27   | sdu | admission | note | tuesday | ,    | apr  | 27   | ,    | 2073 | lujan | ,    | victor | smh      | 0189233 | 54  | ym | sdu | admission | : | 04   | /    | 27   | /    | 73   | pcp | : | elliott | cards | : | alston | chief | complaint | chest | pain | history | of | present | illness | 54  | year | old | man | with | dm1 | for | > | 40  | years | , | esrd | on | hd | , | cad | , | s | / | p | pci | at | vhoc     | and | sipher | stent | to | lad | ( | 100 | % | lesion |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O   | O         | O    | DATE    | DATE | DATE | DATE | DATE | DATE | NAME  | NAME | NAME   | LOCATION | ID      | AGE | O  | O   | O         | O | DATE | DATE | DATE | DATE | DATE | O   | O | NAME    | O     | O | NAME   | O     | O         | O     | O    | O       | O  | O       | O       | AGE | O    | O   | O   | O    | O   | O   | O | O   | O     | O | O    | O  | O  | O | O   | O | O | O | O | O   | O  | LOCATION | O   | O      | O     | O  | O   | O | O   | O | O      |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O   | O         | O    | DATE    | DATE | DATE | DATE | DATE | DATE | NAME  | NAME | NAME   | LOCATION | ID      | AGE | O  | O   | O         | O | DATE | DATE | DATE | DATE | DATE | O   | O | NAME    | O     | O | O      | O     | O         | O     | O    | O       | O  | O       | O       | AGE | O    | O   | O   | O    | O   | O   | O | AGE | O     | O | O    | O  | O  | O | O   | O | O | O | O | O   | O  | O        | O   | O      | O     | O  | O   | O | O   | O | O      |
# _____ Record 211-01 _____
# | Sentence:    | record | date | : | 2093 | -    | 07   | -    | 13   | ccu | jar | admission | note | name | : | urban | ,    | russell | mrn | : | 4722064 | date | of | admission | : | 7    | /    | 09   | /    | 93   | pcp | : | georgia  | cards | : | ward | id | : | 50  | y | / | o | man | transferred | to | ccu | for | wide | complex | tachyarrhythmia | hpi | : | 50  | y | / | o | man | with | no | pmh | and | cardiac | risk | factors | of | smoking | and | family | history | ( | father | died | of | mi | at | age | 41  | ) | who | presented | to | the | ed | with | chest |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O   | O   | O         | O    | O    | O | NAME  | NAME | NAME    | O   | O | ID      | O    | O  | O         | O | DATE | DATE | DATE | DATE | DATE | O   | O | LOCATION | O     | O | O    | O  | O | AGE | O | O | O | O   | O           | O  | O   | O   | O    | O       | O               | O   | O | AGE | O | O | O | O   | O    | O  | O   | O   | O       | O    | O       | O  | O       | O   | O      | O       | O | O      | O    | O  | O  | O  | O   | AGE | O | O   | O         | O  | O   | O  | O    | O     |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O   | O   | O         | O    | O    | O | NAME  | NAME | NAME    | O   | O | ID      | O    | O  | O         | O | DATE | DATE | DATE | DATE | DATE | O   | O | O        | O     | O | O    | O  | O | AGE | O | O | O | O   | O           | O  | O   | O   | O    | O       | O               | O   | O | AGE | O | O | O | O   | O    | O  | O   | O   | O       | O    | O       | O  | O       | O   | O      | O       | O | O      | O    | O  | O  | O  | O   | AGE | O | O   | O         | O  | O   | O  | O    | O     |

# %% [markdown]
# ### Этап 3: Демонстрация качества искусственных примеров личных сущностей
# Правдоподобность искусственных примеров будет оцениваться по метрикам их определения лучшей NER моделью --- BERT-large-uncased, дообученной на i2b2 2014

# %%
# Инициализация алгоритма генерации искусственных сущностей на основе справочника
anonymization = ReferenceBookAnonymization(anon_config['path_to_first_male_names'],
                                           anon_config['path_to_first_femail_names'],
                                           anon_config['path_to_last_names'],
                                           anon_config['path_to_full_addresses'],
                                           anon_config['path_to_countries'],
                                           anon_config['path_to_states'],
                                           anon_config['path_to_cities'],
                                           anon_config['path_to_streets'],
                                           anon_config['path_to_organizations'],
                                           anon_config['path_to_hospitals'],
                                           anon_config['path_to_professions'])

# %%
# Инициализация обезличенного тестового датасета
test_dataset = get_ner_dataset(data_type=i2b2_2014_data_config['val_data_type'],
                               path_to_folder=i2b2_2014_data_config["validate_data_path"], 
                               anonymization=anonymization,
                               is_uncased=True,
                               pretrained_tokenizer=i2b2_2014_data_config["pretrained_tokenizer_path"],
                               max_length=i2b2_2014_data_config["max_token_number"],
                               eq_max_padding=i2b2_2014_data_config["eq_max_padding"])
test_dataloader = DataLoader(test_dataset, shuffle=False,
                             batch_size=i2b2_2014_data_config["batch_size"],
                             collate_fn=test_dataset.get_collate_fn())
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (583 > 512). Running this sequence through the model will result in indexing errors

# %%
# Инициализация модели
t_reader = TensorBoardReader(Path(bert_large_model_config["log_dir"]) / Path("lightning_logs"))
ner_model = PretrainedBertNER.load_from_checkpoint(t_reader.get_ckpt_path())
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Тестирование
trainer_args = {
    "accelerator": "gpu",
    "logger": False
}
trainer = pl.Trainer(**trainer_args, enable_progress_bar=True)
trainer.test(ner_model, test_dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_recall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_precision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /home/dmitry-indenbom/anaconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py:481: UserWarning: You called `self.log('test_f1', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          test_f1            0.9874230027198792
#      test_precision         0.9874230027198792
#        test_recall           0.966221809387207
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_recall': 0.966221809387207,
#   'test_precision': 0.9874230027198792,
#   'test_f1': 0.9874230027198792}]

# %%
# Метрики
stats = Statistics(ner_model, test_dataloader)
print(stats.get_classification_report())
stats.plot_confusion_matrix()
stats.print_random_failed_predictions()
# Out:
#               precision    recall  f1-score   support
#
#         NAME     0.9610    0.9597    0.9603      2157
#   PROFESSION     1.0000    0.2308    0.3750        13
#     LOCATION     0.9197    0.9522    0.9356      3054
#          AGE     0.9666    0.9191    0.9422       346
#         DATE     0.9975    0.9887    0.9931      5233
#           ID     0.9696    0.9369    0.9530      1871
#      CONTACT     0.8402    1.0000    0.9132       589
#            O     0.9678    0.9948    0.9811     38021
#
#    micro avg     0.9659    0.9874    0.9765     51284
#    macro avg     0.9528    0.8728    0.8817     51284
# weighted avg     0.9662    0.9874    0.9765     51284
# Wrongly predicted examples:
# _____ Record 219-03 _____
# | Sentence:    | record | date | : | 16   | -    | 09   | -    | 1969 | st       | .        | joseph   | hospital | of       | eureka   | cornhill | thomas   | melissa  | jamshedpur | , | louisiana | 96971    | 636062883144 | (       | 578     | )       | 114     | -       | 1372    | 17   | /    | 04   | /    | 2053 | history | of | present | illness | : | mr | . | ivan | leslie | is | a | 51  | year | old | male | who | comes | for | follow | up | of | hypertension | , | hyperlipidemia | and | other | medical | problems | . | 1 | . | hypertension | . | continues | on | medications | without | chest | pain | , | shortness | of | breath | , | or | pedal |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | NAME     | NAME     | LOCATION   | O | LOCATION  | LOCATION | ID           | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O       | O  | O       | O       | O | O  | O | NAME | NAME   | O  | O | AGE | O    | O   | O    | O   | O     | O   | O      | O  | O  | O            | O | O              | O   | O     | O       | O        | O | O | O | O            | O | O         | O  | O           | O       | O     | O    | O | O         | O  | O      | O | O  | O     |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | O        | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION   | O | LOCATION  | LOCATION | ID           | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O       | O  | O       | O       | O | O  | O | NAME | NAME   | O  | O | AGE | O    | O   | O    | O   | O     | O   | O      | O  | O  | O            | O | O              | O   | O     | O       | O        | O | O | O | O            | O | O         | O  | O           | O       | O     | O    | O | O         | O  | O      | O | O  | O     |
# _____ Record 385-03 _____
# | Sentence:    | record | date | : | 2046 | /    | may  | /    | 24   | university | hospital | holborn  | circus   | tyler    | becky    | whyalla  | , | west     | virginia | 83098    | 122169364250 | (       | 874     | )       | 660     | -       | 8169    | 27   | /    | july | /    | 2071 | reason | for | visit | : | follow | up | with | mr | . | anthony | frances | who | is | here | with | his | son | and | daughter | - | in | - | law | with | multiple | problems | and | for | preop | check | of | electrolytes | . | mr | . | ronnie | myrtle | is | 14  | years | old | . | medical | problem | list | : | 1 | . | diabetes |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION   | LOCATION | LOCATION | LOCATION | NAME     | NAME     | LOCATION | O | LOCATION | LOCATION | LOCATION | ID           | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O      | O   | O     | O | O      | O  | O    | O  | O | NAME    | NAME    | O   | O  | O    | O    | O   | O   | O   | O        | O | O  | O | O   | O    | O        | O        | O   | O   | O     | O     | O  | O            | O | O  | O | NAME   | NAME   | O  | AGE | O     | O   | O | O       | O       | O    | O | O | O | O        |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION   | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | O | LOCATION | LOCATION | LOCATION | ID           | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O      | O   | O     | O | O      | O  | O    | O  | O | NAME    | NAME    | O   | O  | O    | O    | O   | O   | O   | O        | O | O  | O | O   | O    | O        | O        | O   | O   | O     | O     | O  | O            | O | O  | O | NAME   | NAME   | O  | AGE | O     | O   | O | O       | O       | O    | O | O | O | O        |
# _____ Record 190-03 _____
# | Sentence:    | record | date | : | 2092 | /    | 10   | /    | 13   | swedish  | medical  | center   | ballard  | mark     | lane     | jeffery  | elizabeth | mill     | park     | , | new      | york     | 38180    | 723208666388 | (       | 921     | )       | 493     | -       | 3394    | 22   | /    | 07   | /    | 2027 | history | of | present | illness | : | mr | . | leon | sylvia | is | a | 69  | - | year | - | old | male | who | presented | to | lakes    | region   | general  | hospital | this | evening | for | diabetes | followup | . | he | denies | any | known | drug | allergies | and | at | present | , | he | is | taking | feratab | 300 | mg | t | . |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | NAME     | NAME      | LOCATION | LOCATION | O | LOCATION | LOCATION | LOCATION | ID           | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O       | O  | O       | O       | O | O  | O | NAME | NAME   | O  | O | AGE | O | O    | O | O   | O    | O   | O         | O  | LOCATION | LOCATION | LOCATION | LOCATION | O    | O       | O   | O        | O        | O | O  | O      | O   | O     | O    | O         | O   | O  | O       | O | O  | O  | O      | O       | O   | O  | O | O |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION | LOCATION  | LOCATION | LOCATION | O | LOCATION | LOCATION | LOCATION | ID           | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | CONTACT | DATE | DATE | DATE | DATE | DATE | O       | O  | O       | O       | O | O  | O | NAME | NAME   | O  | O | AGE | O | O    | O | O   | O    | O   | O         | O  | LOCATION | LOCATION | LOCATION | LOCATION | O    | O       | O   | O        | O        | O | O  | O      | O   | O     | O    | O         | O   | O  | O       | O | O  | O  | O      | O       | O   | O  | O | O |
# _____ Record 135-01 _____
# | Sentence:    | record | date | : | 08   | -    | 06   | -    | 1989 | intern | transfer | note | jeffrey | bobbie | mr | # | 246154 | date | of | admission | : | 09   | /    | 07   | /    | 1930 | date | of | transfer | : | 1934 | /    | 01   | /    | 21   | pulm     | : | lewis | kristina | pcp | : | derek | penny | ( | santa    | ana      | ) | cards | : | jordan | bobbie | id | / | cc | : | sob | hpi | : | ms | . | bobby | arlene | is | a | 27  | yo | woman | w | / | a | pmh | notable | for | copd | w | / | fev1 | / | fvc | = | 63 | % | , | hocm | s | / | p | mvr |
# | True labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O      | O        | O    | NAME    | NAME   | O  | O | ID     | O    | O  | O         | O | DATE | DATE | DATE | DATE | DATE | O    | O  | O        | O | DATE | DATE | DATE | DATE | DATE | O        | O | NAME  | NAME     | O   | O | NAME  | NAME  | O | LOCATION | LOCATION | O | O     | O | NAME   | NAME   | O  | O | O  | O | O   | O   | O | O  | O | NAME  | NAME   | O  | O | AGE | O  | O     | O | O | O | O   | O       | O   | O    | O | O | O    | O | O   | O | O  | O | O | O    | O | O | O | O   |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | DATE | DATE | O      | O        | O    | NAME    | NAME   | O  | O | ID     | O    | O  | O         | O | DATE | DATE | DATE | DATE | DATE | O    | O  | O        | O | DATE | DATE | DATE | DATE | DATE | LOCATION | O | NAME  | NAME     | O   | O | NAME  | NAME  | O | LOCATION | LOCATION | O | O     | O | NAME   | NAME   | O  | O | O  | O | O   | O   | O | O  | O | NAME  | NAME   | O  | O | AGE | O  | O     | O | O | O | O   | O       | O   | O    | O | O | O    | O | O   | O | O  | O | O | O    | O | O | O | O   |
# _____ Record 343-02 _____
# | Sentence:    | record | date | : | 07   | 15   | 2042 | palms    | of       | pasadena | hospital | emergency | dept | visit | david | lisa | 4343    | visit | date | : | sep  | -    | 03   | -    | 1974 | the | patient | was | seen | primarily | by | me | . | presenting | complaint | : | fall | , | right | knee | injury | . | history | of | presenting | complaint | : | mr | . | steven | gertrude | is | a | very | pleasant | 88  | - | year | - | old | gentleman | , | with | a | history | of | diabetes | , | who | had | a | fall | on | 1993 | -    | 01   | -    | 18   | . | at | the | time | , | he | sustained | an | injury | to | his | right | knee | which | healed | and | then | began | to | break | down |
# | True labels: | O      | O    | O | DATE | DATE | DATE | LOCATION | LOCATION | LOCATION | LOCATION | O         | O    | O     | NAME  | NAME | ID      | O     | O    | O | DATE | DATE | DATE | DATE | DATE | O   | O       | O   | O    | O         | O  | O  | O | O          | O         | O | O    | O | O     | O    | O      | O | O       | O  | O          | O         | O | O  | O | NAME   | NAME     | O  | O | O    | O        | AGE | O | O    | O | O   | O         | O | O    | O | O       | O  | O        | O | O   | O   | O | O    | O  | DATE | DATE | DATE | DATE | DATE | O | O  | O   | O    | O | O  | O         | O  | O      | O  | O   | O     | O    | O     | O      | O   | O    | O     | O  | O     | O    |
# | Pred labels: | O      | O    | O | DATE | DATE | DATE | LOCATION | LOCATION | LOCATION | LOCATION | O         | O    | O     | NAME  | NAME | CONTACT | O     | O    | O | DATE | DATE | DATE | DATE | DATE | O   | O       | O   | O    | O         | O  | O  | O | O          | O         | O | O    | O | O     | O    | O      | O | O       | O  | O          | O         | O | O  | O | NAME   | NAME     | O  | O | O    | O        | AGE | O | O    | O | O   | O         | O | O    | O | O       | O  | O        | O | O   | O   | O | O    | O  | DATE | DATE | DATE | DATE | DATE | O | O  | O   | O    | O | O  | O         | O  | O      | O  | O   | O     | O    | O     | O      | O   | O    | O     | O  | O     | O    |

# %% [markdown]
# В целом все метки предсказываются с той же точностью, что и первоначальные, за исключением метки 'CONTACT'.
# Основная трудность для модели заключается в предсказании номеров телефона. Возможно, ошибкой был выбор российского стандарта их написания.
# Продемонстрируем примеры только с данной ошибкой:

# %%
faults = stats.get_specific_failed_predictions('CONTACT')
# Out:
# Wrongly predicted examples:

# %% [markdown]
# Как видно, в оригинальных данных не используется код страны, и цифры сгруппированы по-другому.
# Запись **347-03**
# Original:  (121) 537-3484
# Synthetic: +1 933 257-12-32
# Запись **314-02**
# Original:  (676) 312-7662
# Synthetic: +1 995 672-52-24
#
# Ещё один вариант записи номера телефона в оригинальных данных: "665-578-7821"

# %% [markdown]
# ### Этап 4: Дополнительное исследование данных
